# %%
# Settings

# %%
from IPython.core.display import HTML
HTML("""
<style>
    h1{background-color:black; color:white; padding: 10px 10px 10px 10px}
    h2{background-color:blue; color:white;  padding: 5px 5px 5px 5px}
</style>
""")
# Out:
# <style>
#     h1{background-color:black; color:white; padding: 10px 10px 10px 10px}
#     h2{background-color:blue; color:white;  padding: 5px 5px 5px 5px}
# </style>

# %%
# %matplotlib inline

# %% [markdown]
# # Parameters

# %%
# Mode to run the script with.  Either 'cjc' or 'lspbs'
mode = 'cjc' 

# Max number of case types to be generate the summaries for
n_casetypes = 10

# Min number of cases in for each case type in order to run summarization
threshold = 100

# Number of key phrases to be extracted for summary
phrase_limit = 50

# Word limit for significant sentences to be included in top sentences generator before (excluding similar ones)
word_limit = 1000

# Parameter to exclude sentences that are too similar from the list of top sentences.  
# Acceptable values: between 0.0 and 1.0 inclusive
# E.g., if sim_score_threshold = 0.9, sentences that are >= 90% similar will be excluded
sim_score_threshold = 0.9

# Boolean parameter for printing out intermediate outputs (not very useful for now)
to_print = False

# Boolean parameter for plotting the network graph
to_plot = False

# %% [markdown]
# # Install dependencies

# %%
# !pip install pytextrank networkx xlrd
# Out:
# Requirement already satisfied: pytextrank in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: networkx in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: xlrd in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: spacy in /opt/conda/lib/python3.6/site-packages (from pytextrank)
# Requirement already satisfied: datasketch in /opt/conda/lib/python3.6/site-packages (from pytextrank)
# Requirement already satisfied: statistics in /opt/conda/lib/python3.6/site-packages (from pytextrank)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.6/site-packages (from pytextrank)
# Requirement already satisfied: decorator>=4.1.0 in /opt/conda/lib/python3.6/site-packages (from networkx)
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: pathlib in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: thinc<6.6.0,>=6.5.0 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: cymem<1.32,>=1.30 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.6/site-packages (from spacy->pytextrank)
# Requirement already satisfied: redis>=2.10.0 in /opt/conda/lib/python3.6/site-packages (from datasketch->pytextrank)
# Requirement already satisfied: docutils>=0.3 in /opt/conda/lib/python3.6/site-packages (from statistics->pytextrank)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy->pytextrank)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy->pytextrank)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy->pytextrank)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy->pytextrank)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy->pytextrank)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /opt/conda/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy->pytextrank)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy->pytextrank)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy->pytextrank)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy->pytextrank)
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Load libraries

# %%
import pandas as pd
import numpy as np
import re
import string

import spacy
from spacy.en.word_sets import STOP_WORDS

import pytextrank

from collections import Counter

import pylab as plt

from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamodel import LdaModel

import pyLDAvis
import pyLDAvis.gensim


from pprint import pprint
import warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Something to make custom pytextrank work
__file__ = pytextrank.__file__

# %% [markdown]
# # Load data

# %%
harmonization_path = '../../data/anonymising_scripts/harmonize_case_types_combined.py'
case_type_dic_filepath = '../../data/original/case_type_harmonization.csv'

#CJC
if mode.lower() == 'cjc':
    original_file_path = '../../data/original/cjc_cases_20178_sample_20180808.xlsx'
    col_advice = 'LEGAL_ISSUES'
    col_synopsis = 'BACKGROUND_INFORMATION'
    col_casetype = 'CASE_TYPE_CJC'
#LSPBS
elif mode.lower() == 'lspbs':
    original_file_path = '../../data/original/lspbs_cases2016_sample.xlsx'
    col_advice = 'ADVICE_SOUGHT'
    col_synopsis = 'CASE_SYNOPSIS'
    col_casetype = 'CASE_TYPE_LSPBS'

# %run $harmonization_path $original_file_path $mode $case_type_dic_filepath

if re.search(r'xlsx', original_file_path):
    file_path = original_file_path[:-5] + '_harmonized.csv'
else:
    file_path = original_file_path[:-4] + '_harmonized.csv'

df = pd.read_csv(file_path).fillna('')

# %% [markdown]
# # Load spacy model

# %%
spacy.util.set_data_path("../../data/spacy")

# %%
nlp = spacy.load('en_core_web_sm/en_core_web_sm-1.2.0')

# %% [markdown]
# # Update stopwords

# %%
NEW_STOP_WORDS = STOP_WORDS.copy()
custom_stopwords = [
    'adverse','party','applicant',
    'legal','advice','general','guidance','advice','advise',
    'like','know','seeking','lawyers','lawyer','client','help'
    'money','amount','approached applicant','client','time'
]

to_keep = [
    'who','what','when','where','why','how','whether', 'will'
]
to_keep = ['will']
    
for s in custom_stopwords:
    NEW_STOP_WORDS.add(s)

for s in to_keep:
    NEW_STOP_WORDS.remove(s)

# %% [markdown]
# # Modify Pytextrank functions

# %%
#!/usr/bin/env python
# encoding: utf-8

from collections import namedtuple
from datasketch import MinHash
from graphviz import Digraph
import hashlib
import json
import math
import networkx as nx
import os
import os.path
import re
import spacy
import statistics
import string

DEBUG = False # True

ParsedGraf = namedtuple('ParsedGraf', 'id, sha1, graf')
WordNode = namedtuple('WordNode', 'word_id, raw, root, pos, keep, idx')
RankedLexeme = namedtuple('RankedLexeme', 'text, rank, ids, pos, count')
SummarySent = namedtuple('SummarySent', 'dist, idx, text')


######################################################################
## filter the novel text versus quoted text in an email message

PAT_FORWARD = re.compile("\n\-+ Forwarded message \-+\n")
PAT_REPLIED = re.compile("\nOn.*\d+.*\n?wrote\:\n+\>")
PAT_UNSUBSC = re.compile("\n\-+\nTo unsubscribe,.*\nFor additional commands,.*")


def split_grafs (lines):
    """
    segment the raw text into paragraphs
    """
    graf = []

    for line in lines:
        line = line.strip()

        if len(line) < 1:
            if len(graf) > 0:
                yield "\n".join(graf)
                graf = []
        else:
            graf.append(line)

    if len(graf) > 0:
        yield "\n".join(graf)


def filter_quotes (text, is_email=True):
    """
    filter the quoted text out of a message
    """
    global DEBUG
    global PAT_FORWARD, PAT_REPLIED, PAT_UNSUBSC

    if is_email:
        text = filter(lambda x: x in string.printable, text)

        if DEBUG:
            print("text:", text)

        # strip off quoted text in a forward
        m = PAT_FORWARD.split(text, re.M)

        if m and len(m) > 1:
            text = m[0]

        # strip off quoted text in a reply
        m = PAT_REPLIED.split(text, re.M)

        if m and len(m) > 1:
            text = m[0]

        # strip off any trailing unsubscription notice
        m = PAT_UNSUBSC.split(text, re.M)

        if m:
            text = m[0]

    # replace any remaining quoted text with blank lines
    lines = []

    for line in text.split("\n"):
        if line.startswith(">"):
            lines.append("")
        else:
            lines.append(line)

    return list(split_grafs(lines))


######################################################################
## parse and markup text paragraphs for semantic analysis

PAT_PUNCT = re.compile(r'^\W+$')
PAT_SPACE = re.compile(r'\_+$')

POS_KEEPS = ['v', 'n', 'j']
POS_LEMMA = ['v', 'n']
UNIQ_WORDS = { ".": 0 }


def is_not_word (word):
    return PAT_PUNCT.match(word) or PAT_SPACE.match(word)


def get_word_id (root):
    """
    lookup/assign a unique identify for each word root
    """
    global UNIQ_WORDS

    # in practice, this should use a microservice via some robust
    # distributed cache, e.g., Redis, Cassandra, etc.
    if root not in UNIQ_WORDS:
        UNIQ_WORDS[root] = len(UNIQ_WORDS)

    return UNIQ_WORDS[root]


def fix_microsoft (foo):
    """
    fix special case for `c#`, `f#`, etc.; thanks Microsoft
    """
    i = 0
    bar = []

    while i < len(foo):
        text, lemma, pos, tag = foo[i]

        if (text == "#") and (i > 0):
            prev_tok = bar[-1]

            prev_tok[0] += "#"
            prev_tok[1] += "#"

            bar[-1] = prev_tok
        else:
            bar.append(foo[i])

        i += 1

    return bar


def fix_hypenation (foo):
    """
    fix hyphenation in the word list for a parsed sentence
    """
    i = 0
    bar = []

    while i < len(foo):
        text, lemma, pos, tag = foo[i]

        if (tag == "HYPH") and (i > 0) and (i < len(foo) - 1):
            prev_tok = bar[-1]
            next_tok = foo[i + 1]

            prev_tok[0] += "-" + next_tok[0]
            prev_tok[1] += "-" + next_tok[1]

            bar[-1] = prev_tok
            i += 2
        else:
            bar.append(foo[i])
            i += 1

    return bar


def parse_graf (doc_id, graf_text, base_idx, spacy_nlp=None):
    """
    CORE ALGORITHM: parse and markup sentences in the given paragraph
    """
    global DEBUG
    global POS_KEEPS, POS_LEMMA, SPACY_NLP

    # set up the spaCy NLP parser
    if not spacy_nlp:
        if not SPACY_NLP:
            SPACY_NLP = spacy.load("en_core_web_sm/en_core_web_sm-1.2.0")

        spacy_nlp = SPACY_NLP

    markup = []
    new_base_idx = base_idx
    doc = spacy_nlp(graf_text, parse=True)

    for span in doc.sents:
        graf = []
        digest = hashlib.sha1()

        if DEBUG:
            print(span)

        # build a word list, on which to apply corrections
        word_list = []

        for tag_idx in range(span.start, span.end):
            token = doc[tag_idx]

            if DEBUG:
                print("IDX", tag_idx, token.text, token.tag_, token.pos_)
                print("reg", is_not_word(token.text))

            word_list.append([token.text, token.lemma_, token.pos_, token.tag_])

        # scan the parsed sentence, annotating as a list of `WordNode`
        corrected_words = fix_microsoft(fix_hypenation(word_list))

        for tok_text, tok_lemma, tok_pos, tok_tag in corrected_words:
            word = WordNode(word_id=0, raw=tok_text, root=tok_text.lower(), pos=tok_tag, keep=0, idx=new_base_idx)

            if is_not_word(tok_text) or (tok_tag == "SYM"):
                # a punctuation, or other symbol
                pos_family = '.'
                word = word._replace(pos=pos_family)
            else:
                pos_family = tok_tag.lower()[0]

            if pos_family in POS_LEMMA:
                # can lemmatize this word?
                word = word._replace(root=tok_lemma)

            if pos_family in POS_KEEPS:
                word = word._replace(word_id=get_word_id(word.root), keep=1)

            digest.update(word.root.encode('utf-8'))

            # schema: word_id, raw, root, pos, keep, idx
            if DEBUG:
                print(word)

            graf.append(list(word))
            new_base_idx += 1

        markup.append(ParsedGraf(id=doc_id, sha1=digest.hexdigest(), graf=graf))

    return markup, new_base_idx


def parse_doc (json_iter):
    """
    parse one document to prep for TextRank
    """
    global DEBUG

    for meta in json_iter:
        base_idx = 0

        for graf_text in filter_quotes(meta["text"], is_email=False):
            if DEBUG:
                print("graf_text:", graf_text)

            grafs, new_base_idx = parse_graf(meta["id"], graf_text, base_idx)
            base_idx = new_base_idx

            for graf in grafs:
                yield graf


######################################################################
## graph analytics

def get_tiles (graf, size=3):
    """
    generate word pairs for the TextRank graph
    """
    keeps = list(filter(lambda w: w.word_id > 0, graf))
    keeps_len = len(keeps)

    for i in iter(range(0, keeps_len - 1)):
        w0 = keeps[i]

        for j in iter(range(i + 1, min(keeps_len, i + 1 + size))):
            w1 = keeps[j]

            if (w1.idx - w0.idx) <= size:
                yield (w0.root, w1.root,)


def build_graph (json_iter):
    """
    construct the TextRank graph from parsed paragraphs
    """
    global DEBUG, WordNode
    graph = nx.DiGraph()

    for meta in json_iter:
        if DEBUG:
            print(meta["graf"])

        for pair in get_tiles(map(WordNode._make, meta["graf"])):
            if DEBUG:
                print(pair)

            for word_id in pair:
                if not graph.has_node(word_id):
                    graph.add_node(word_id)

            try:
                graph.adj[pair[0]][pair[1]]["weight"] += 1.0
            except KeyError:
                graph.add_edge(pair[0], pair[1], weight=1.0)

    return graph


def write_dot (graph, ranks, path="graph.dot"):
    """
    output the graph in Dot file format
    """
    dot = Digraph()

    for node in graph.nodes():
        dot.node(node, "%s %0.3f" % (node, ranks[node]))

    for edge in graph.edges():
        dot.edge(edge[0], edge[1], constraint="false")

    with open(path, 'w') as f:
        f.write(dot.source)


def render_ranks (graph, ranks, dot_file="graph.dot"):
    """
    render the TextRank graph for visual formats
    """
    if dot_file:
        write_dot(graph, ranks, path=dot_file)

    ## omitted since matplotlib isn't reliable enough
    #import matplotlib.pyplot as plt
    #nx.draw_networkx(graph)
    #plt.savefig(img_file)
    #plt.show()


def text_rank (path):
    """
    run the TextRank algorithm
    """
    graph = build_graph(json_iter(path))
    ranks = nx.pagerank(graph)

    return graph, ranks


######################################################################
## collect key phrases

SPACY_NLP = None
STOPWORDS = NEW_STOP_WORDS

STOPWORDS
def load_stopwords (stop_file):
    stopwords = set([])

    # provide a default if needed
    if not stop_file:
        stop_file = "stop.txt"

    # check whether the path is fully qualified
    if os.path.isfile(stop_file):
        stop_path = stop_file

    # check for the file in the current working directory
    else:
        cwd = os.getcwd()
        stop_path = os.path.join(cwd, stop_file)

        # check for the file in the same directory as this code module
        if not os.path.isfile(stop_path):
            loc = os.path.realpath( os.path.join(cwd, os.path.dirname(__file__)) )
            stop_path = os.path.join(loc, stop_file)

    try:
        with open(stop_path, "r") as f:
            for line in f.readlines():
                stopwords.add(line.strip().lower())
    except FileNotFoundError:
        pass

    return stopwords


def find_chunk_sub (phrase, np, i):
    for j in iter(range(0, len(np))):
        p = phrase[i + j]

        if p.text != np[j]:
            return None

    return phrase[i:i + len(np)]


def find_chunk (phrase, np):
    """
    leverage noun phrase chunking
    """
    for i in iter(range(0, len(phrase))):
        parsed_np = find_chunk_sub(phrase, np, i)

        if parsed_np:
            return parsed_np


def enumerate_chunks (phrase, spacy_nlp):
    """
    iterate through the noun phrases
    """
    if (len(phrase) > 1):
        found = False
        text = " ".join([rl.text for rl in phrase])
        doc = spacy_nlp(text.strip(), parse=True)

        for np in doc.noun_chunks:
            if np.text != text:
                found = True
                yield np.text, find_chunk(phrase, np.text.split(" "))

        if not found and all([rl.pos[0] != "v" for rl in phrase]):
            yield text, phrase


def collect_keyword (sent, ranks, stopwords):
    """
    iterator for collecting the single-word keyphrases
    """
    for w in sent:
        if (w.word_id > 0) and (w.root in ranks) and (w.pos[0] in "NV") and (w.root not in stopwords):
            rl = RankedLexeme(text=w.raw.lower(), rank=ranks[w.root]/2.0, ids=[w.word_id], pos=w.pos.lower(), count=1)

            if DEBUG:
                print(rl)

            yield rl


def find_entity (sent, ranks, ent, i):
    if i >= len(sent):
        return None, None
    else:
        for j in iter(range(0, len(ent))):
            w = sent[i + j]

            if w.raw != ent[j]:
                return find_entity(sent, ranks, ent, i + 1)

        w_ranks = []
        w_ids = []

        for w in sent[i:i + len(ent)]:
            w_ids.append(w.word_id)

            if w.root in ranks:
                w_ranks.append(ranks[w.root])
            else:
                w_ranks.append(0.0)

        return w_ranks, w_ids


def collect_entities (sent, ranks, stopwords, spacy_nlp):
    """
    iterator for collecting the named-entities
    """
    global DEBUG
    sent_text = " ".join([w.raw for w in sent])

    if DEBUG:
        print("sent:", sent_text)

    for ent in spacy_nlp(sent_text).ents:
        if DEBUG:
            print("NER:", ent.label_, ent.text)

        if (ent.label_ not in ["CARDINAL"]) and (ent.text.lower() not in stopwords):
            w_ranks, w_ids = find_entity(sent, ranks, ent.text.split(" "), 0)

            if w_ranks and w_ids:
                rl = RankedLexeme(text=ent.text.lower(), rank=w_ranks, ids=w_ids, pos="np", count=1)

                if DEBUG:
                    print(rl)

                yield rl


def collect_phrases (sent, ranks, spacy_nlp):
    """
    iterator for collecting the noun phrases
    """
    tail = 0
    last_idx = sent[0].idx - 1
    phrase = []

    while tail < len(sent):
        w = sent[tail]

        if (w.word_id > 0) and (w.root in ranks) and ((w.idx - last_idx) == 1):
            # keep collecting...
            rl = RankedLexeme(text=w.raw.lower(), rank=ranks[w.root], ids=w.word_id, pos=w.pos.lower(), count=1)
            phrase.append(rl)
        else:
            # just hit a phrase boundary
            for text, p in enumerate_chunks(phrase, spacy_nlp):
                if p:
                    id_list = [rl.ids for rl in p]
                    rank_list = [rl.rank for rl in p]
                    np_rl = RankedLexeme(text=text, rank=rank_list, ids=id_list, pos="np", count=1)

                    if DEBUG:
                        print(np_rl)

                    yield np_rl

            phrase = []

        last_idx = w.idx
        tail += 1


def calc_rms (values):
    """
    calculate a root-mean-squared metric for a list of float values
    """
    #return math.sqrt(sum([x**2.0 for x in values])) / float(len(values))
    # take the max() which works fine
    return max(values)


def normalize_key_phrases (path, ranks, stopwords=None, spacy_nlp=None, skip_ner=True):
    """
    collect keyphrases, named entities, etc., while removing stop words
    """
    global STOPWORDS, SPACY_NLP

    # set up the stop words
    if (type(stopwords) is list) or (type(stopwords) is set):
        # explicit conversion to a set, for better performance
        stopwords = set(stopwords)
    else:
        if not STOPWORDS:
            STOPWORDS = load_stopwords(stopwords)

        stopwords = STOPWORDS

    # set up the spaCy NLP parser
    if not spacy_nlp:
        if not SPACY_NLP:
            SPACY_NLP = spacy.load("en_core_web_sm/en_core_web_sm-1.2.0")

        spacy_nlp = SPACY_NLP

    # collect keyphrases
    single_lex = {}
    phrase_lex = {}

    if isinstance(path, str):
        path = json_iter(path)

    for meta in path:
        sent = [w for w in map(WordNode._make, meta["graf"])]

        for rl in collect_keyword(sent, ranks, stopwords):
            id = str(rl.ids)

            if id not in single_lex:
                single_lex[id] = rl
            else:
                prev_lex = single_lex[id]
                single_lex[id] = rl._replace(count = prev_lex.count + 1)

        if not skip_ner:
            for rl in collect_entities(sent, ranks, stopwords, spacy_nlp):
                id = str(rl.ids)

                if id not in phrase_lex:
                    phrase_lex[id] = rl
                else:
                    prev_lex = phrase_lex[id]
                    phrase_lex[id] = rl._replace(count = prev_lex.count + 1)

        for rl in collect_phrases(sent, ranks, spacy_nlp):
            id = str(rl.ids)

            if id not in phrase_lex:
                phrase_lex[id] = rl
            else:
                prev_lex = phrase_lex[id]
                phrase_lex[id] = rl._replace(count = prev_lex.count + 1)

    # normalize ranks across single keywords and longer phrases:
    #    * boost the noun phrases based on their length
    #    * penalize the noun phrases for repeated words
    rank_list = [rl.rank for rl in single_lex.values()]

    if len(rank_list) < 1:
        max_single_rank = 0
    else:
        max_single_rank = max(rank_list)

    repeated_roots = {}

    for rl in sorted(phrase_lex.values(), key=lambda rl: len(rl), reverse=True):
        rank_list = []

        for i in iter(range(0, len(rl.ids))):
            id = rl.ids[i]

            if not id in repeated_roots:
                repeated_roots[id] = 1.0
                rank_list.append(rl.rank[i])
            else:
                repeated_roots[id] += 1.0
                rank_list.append(rl.rank[i] / repeated_roots[id])

        phrase_rank = calc_rms(rank_list)
        single_lex[str(rl.ids)] = rl._replace(rank = phrase_rank)

    # scale all the ranks together, so they sum to 1.0
    sum_ranks = sum([rl.rank for rl in single_lex.values()])

    for rl in sorted(single_lex.values(), key=lambda rl: rl.rank, reverse=True):
        if sum_ranks > 0.0:
            rl = rl._replace(rank=rl.rank / sum_ranks)
        elif rl.rank == 0.0:
            rl = rl._replace(rank=0.1)

        rl = rl._replace(text=re.sub(r"\s([\.\,\-\+\:\@])\s", r"\1", rl.text))
        yield rl


######################################################################
## sentence significance

def mh_digest (data):
    """
    create a MinHash digest
    """
    num_perm = 512
    m = MinHash(num_perm)

    for d in data:
        m.update(d.encode('utf8'))

    return m


def rank_kernel (path):
    """
    return a list (matrix-ish) of the key phrases and their ranks
    """
    kernel = []

    if isinstance(path, str):
        path = json_iter(path)

    for meta in path:
        if not isinstance(meta, RankedLexeme):
            rl = RankedLexeme(**meta)
        else:
            rl = meta

        m = mh_digest(map(lambda x: str(x), rl.ids))
        kernel.append((rl, m,))

    return kernel


def top_sentences (kernel, path):
    """
    determine distance for each sentence
    """
    key_sent = {}
    i = 0

    if isinstance(path, str):
        path = json_iter(path)

    for meta in path:
        graf = meta["graf"]
        tagged_sent = [WordNode._make(x) for x in graf]
        text = " ".join([w.raw for w in tagged_sent])

        m_sent = mh_digest([str(w.word_id) for w in tagged_sent])
        dist = sum([m_sent.jaccard(m) * rl.rank for rl, m in kernel])
        key_sent[text] = (dist, i)
        i += 1

    for text, (dist, i) in sorted(key_sent.items(), key=lambda x: x[1][0], reverse=True):
        yield SummarySent(dist=dist, idx=i, text=text)


######################################################################
## document summarization

def limit_keyphrases (path, phrase_limit=20):
    """
    iterator for the most significant key phrases
    """
    rank_thresh = None

    if isinstance(path, str):
        lex = []

        for meta in json_iter(path):
            rl = RankedLexeme(**meta)
            lex.append(rl)
    else:
        lex = path

    if len(lex) > 0:
        rank_thresh = statistics.mean([rl.rank for rl in lex])
    else:
            rank_thresh = 0

    used = 0

    for rl in lex:
        if rl.pos[0] != "v":
            if (used > phrase_limit) or (rl.rank < rank_thresh):
                return

            used += 1
            yield rl.text.replace(" - ", "-")


def limit_sentences (path, word_limit=100):
    """
    iterator for the most significant sentences, up to a specified limit
    """
    word_count = 0

    if isinstance(path, str):
        path = json_iter(path)

    for meta in path:
        if not isinstance(meta, SummarySent):
            p = SummarySent(**meta)
        else:
            p = meta

        sent_text = p.text.strip().split(" ")
        sent_len = len(sent_text)

        if (word_count + sent_len) > word_limit:
            break
        else:
            word_count += sent_len
            yield sent_text, p.idx, p.dist


def make_sentence (sent_text):
    """
    construct a sentence text, with proper spacing
    """
    lex = []
    idx = 0

    for word in sent_text:
        if len(word) > 0:
            if (idx > 0) and not (word[0] in ",.:;!?-\"'"):
                lex.append(" ")

            lex.append(word)

        idx += 1

    return "".join(lex)


######################################################################
## common utilities

def json_iter (path):
    """
    iterator for JSON-per-line in a file pattern
    """
    with open(path, 'r') as f:
        for line in f.readlines():
            yield json.loads(line)


def pretty_print (obj, indent=False):
    """
    pretty print a JSON object
    """

    if indent:
        return json.dumps(obj, sort_keys=True, indent=2, separators=(',', ': '))
    else:
        return json.dumps(obj, sort_keys=True)

# %% [markdown]
# #  Function to extract summary

# %%
def textrank_generate(df, 
                      case_type, 
                      col='advice',
                      sim_score_threshold=0.9, 
                      phrase_limit=30, 
                      word_limit=1000, 
                      to_print=False, 
                      to_plot=True):
    
    """
    Takes in the cleaned and harmonized case detail Pandas DataFrame, 
    performs some text processing, 
    tokenizes words using spacy-en language model and 
    prints out key phrases and summaries. 
    
    Arguments
    @ df                  : Cleaned and harmonized case detail Pandas DataFrame
    @ casetype            : Case type for which the summary is to be generated
    @ col                 : Column to be used.  Accepts 'advice', 'synopsis' and 'both' only
    @ sim_score_threshold : Float between 0.0 and 1.0 inclusive.  Parameter to exclude sentences that are >= x in cosine similarity from the list of top sentences.  
    @ phrase_limit        : Number of key phrases to be extracted for summary
    @ word_limit          : Word limit for significant sentences to be included in top sentences generator before (excluding similar ones)
    @ to_print            : Boolean parameter.  If True, prints all intermediate outputs from PyTextRank
    @ to_plot             : Boolean parameter.  If True, plots the network graph
    
    Returns
    A tuple: list of key_phrases and significant sentences (as printed out)
    """
    
    # Extract data from column(s) to be used into a single array
    if col.lower()=='both':
        print('\nColumns used: advice and synopsis')
        advice = (df
                  .loc[df[col_casetype] == case_type, col_advice]
                  .append(df
                          .loc[df[col_casetype] == case_type, col_synopsis], 
                          ignore_index=True)
                  .values)
    elif col.lower()=='synopsis':
        print('\nColumn used: synopsis')
        advice = df.loc[df[col_casetype] == case_type, col_synopsis].values
    else:
        print('\nColumn used: advice')
        advice = df.loc[df[col_casetype] == case_type, col_advice].values
    
    # charset = set(list(''.join(advice)))
    
    # Simple text processing
    ## Standardize some short hand notation
    advice = [adv.replace('A/P',' Adverse Party ') for adv in advice] 
    ## Separate '#1', '#2' etc from 'Adverse Party' string to improve keyword outputs
    advice = [adv.replace('#',' #') for adv in advice]  
    ## Create a single long text separated by spaces after replacing double quotes as apostrophes with single quote
    advice_all = '. '.join(advice).replace('"', '\'')  # 
    ## Convert to required json string format for PyTextRank
    advice_json = '{"id":"1", "text":"' + advice_all + '"}'
    
    path_stage0 = 'advice.json'
    path_stage1 = 'ol.json'
    path_stage2 = "o2.json"
    path_stage3 = "o3.json"
    
    with open(path_stage0, 'w') as f:
        f.write(advice_json)
    
    with open(path_stage1, 'w') as f:
        for graf in parse_doc(json_iter(path_stage0)):
            f.write("%s\n" % pretty_print(graf._asdict()))
            
            if to_print:
                # to view output in this notebook
                print(pretty_print(graf))
    
    graph, ranks = text_rank(path_stage1)
    render_ranks(graph, ranks)
    
    with open(path_stage2, 'w') as f:
        for rl in normalize_key_phrases(path_stage1, ranks):
            f.write("%s\n" % pretty_print(rl._asdict()))
            
            if to_print:
                # to view output in this notebook
                print(pretty_print(rl))
    
    if to_plot:
        plt.figure(1, figsize = (12, 12))
        nx.draw(graph, with_labels=True) 
        plt.show()
    
    
    kernel = rank_kernel(path_stage2)

    with open(path_stage3, 'w') as f:
        for s in top_sentences(kernel, path_stage1):
            f.write(pretty_print(s._asdict()))
            f.write("\n")
            
            if to_print:
                # to view output in this notebook
                print(pretty_print(s._asdict()))
    
    phrases = ", ".join(set([p for p in limit_keyphrases(path_stage2, phrase_limit=phrase_limit)]))
    sent_iter = sorted(limit_sentences(path_stage3, word_limit=word_limit), key=lambda x: x[2], reverse=True)
    s = []
    
    sent_text_list = []
    counter = 1
    for sent_text, idx, dist in sent_iter:
        if len(sent_text_list) == 0:
            sim_score_prev = 0.
            sent_text_list.append(nlp(make_sentence(sent_text)))
            s.append('sentence_' + 
                     str(counter) + 
                     ': (dist :' + 
                     str(round(dist, 5)) + 
                     ')\n\t - ' + 
                     make_sentence(sent_text))
            counter += 1
        else:
            sim_text_curr = nlp(make_sentence(sent_text))
            max_sim_score = max([sent_text_prev.similarity(sim_text_curr) for sent_text_prev in sent_text_list])
            if max_sim_score < sim_score_threshold:
                sent_text_list.append(sim_text_curr)
                s.append('sentence_' + 
                         str(counter) + 
                         ': (dist :' + 
                        str(round(dist, 5)) + 
                         ')\n\t - ' + 
                         make_sentence(sent_text))
                counter += 1

    graf_text = "\n".join(s)
    
    print("**excerpts:**\n%s\n\n**keywords:**\n%s" % (graf_text, phrases,))
    
    return phrases, graf_text

# %% [markdown]
# # Extract top case types

# %%
top_n_casestypes = (df
                    .loc[:, [col_casetype, col_advice]]
                    .groupby(col_casetype, as_index=False)
                    .agg('count')
                    .sort_values(col_advice, ascending=False)
                    .iloc[:n_casetypes, :]
                   )

top_n_casestypes = (top_n_casestypes
                    .loc[top_n_casestypes[col_advice] >= threshold, :]
                   ).values

# %% [markdown]
# # Generate Summaries

# %% [markdown]
# ## Advice only

# %%
out_advice = {}

for casetype, num_cases in top_n_casestypes:
    print('\n\n\nCasetype: ' + 
          casetype + 
          ' (' + 
          str(num_cases) + 
          ' cases)')
    
    out_advice[casetype] = textrank_generate(df, 
                                             casetype, 
                                             col='advice', 
                                             sim_score_threshold=sim_score_threshold, 
                                             phrase_limit=phrase_limit, 
                                             word_limit=word_limit, 
                                             to_print=to_print, 
                                             to_plot=to_plot)
# Out:
# Casetype: Bankruptcy / DRS (804 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.05046)
# 	 - How to file a bankruptcy application?
# sentence_2: (dist :0.04843)
# 	 - Should the applicant file for bankruptcy himself?
# sentence_3: (dist :0.04451)
# 	 - Filling up of bankruptcy application form.
# sentence_4: (dist :0.04404)
# 	 - Can the applicant self-declare bankruptcy instead.
# sentence_5: (dist :0.04152)
# 	 - How to avoid bankruptcy from the bank?.
# sentence_6: (dist :0.0396)
# 	 - Restrictions after declaring bankruptcy..
# sentence_7: (dist :0.03863)
# 	 - What is the procedure for bankruptcy proceedings?
# sentence_8: (dist :0.03858)
# 	 - Will his employer know of his bankruptcy?
# sentence_9: (dist :0.03812)
# 	 - ( 5 ) When can Applicant be discharged from bankruptcy?.
# sentence_10: (dist :0.03792)
# 	 - The applicant now wishes to apply for bankruptcy..
# sentence_11: (dist :0.03776)
# 	 - Bankruptcy proceedings; process of DRS..
# sentence_12: (dist :0.03756)
# 	 - Applicant wants to resist the bankruptcy application.
# sentence_13: (dist :0.03718)
# 	 - What are the implications of bankruptcy.
# sentence_14: (dist :0.03695)
# 	 - What is self-declared bankruptcy?
# sentence_15: (dist :0.03599)
# 	 - How can applicant annul his bankruptcy status?.
# sentence_16: (dist :0.03481)
# 	 - The applicant would like a bankruptcy protection..
# sentence_17: (dist :0.03481)
# 	 - Filing for bankruptcy procedural questions.
# sentence_18: (dist :0.03425)
# 	 - Applicant would like to self declare bankruptcy..
# sentence_19: (dist :0.03398)
# 	 - How to file for bankruptcy and fill in Bankruptcy Forms 9, 10, 11 and 12.
# sentence_20: (dist :0.03387)
# 	 - Would filing bankruptcy stop a lawsuit?
# sentence_21: (dist :0.03351)
# 	 - Can the bankruptcy proceedings supercede the appeal?
# sentence_22: (dist :0.03265)
# 	 - Whether his forms for self-filing of bankruptcy are in order.
# sentence_23: (dist :0.0318)
# 	 - 1 ) Financial Oligations/ Restrictions after bankruptcy.
# sentence_24: (dist :0.03176)
# 	 - What is the estimated period of his bankruptcy?
# sentence_25: (dist :0.03162)
# 	 - He also inquired about the entire bankruptcy process..
# sentence_26: (dist :0.03107)
# 	 - . Wants to find out about the bankruptcy progress..
# sentence_27: (dist :0.03076)
# 	 - Whether Applicant should sell the house or to declare for bankruptcy.
# sentence_28: (dist :0.02996)
# 	 - Banks offered debt restructuring, applicant refused the debt restructuring.. How to file for bankruptcy?
# sentence_29: (dist :0.02994)
# 	 - The applicant came in for legal advice on his bankruptcy proposal and debt proceedings.
# sentence_30: (dist :0.0299)
# 	 - Enquiring about bankruptcy proceedings. Enquiring more about the self-declaring bankruptcy.
# sentence_31: (dist :0.02914)
# 	 - Whether his banking loans will be affected by the bankruptcy claim.
# sentence_32: (dist :0.02836)
# 	 - Applicant's niece wishes to appeal against the bankruptcy order..
# sentence_33: (dist :0.02789)
# 	 - Will the OA notify the creditors of her bankruptcy or her being under a DRS?
# sentence_34: (dist :0.02754)
# 	 - Can I sell my fully paid HDB once i have filed for bankruptcy.
#
# **keywords:**
# other banks, bankruptcy order, bankruptcy actions, application, self-declared bankruptcy process, bankrupt, drs application procedure, oa discharge, proper payment, other outstanding debts, phillipines property, debt restructuring scheme, documents, bankrupt person, applicant file, banrkruptcy cases, legal advice, judgment sums, bankruptcy suit, application form, bankruptcy application form, help, bankruptcy proceedings, impending bankrupt person, client file, amount, bankruptcy application, housing loans, mr tiong fill, bankruptcy claim, banking loans, loan, applicant self-file, mothers property, hdb loan, court order, employer know, declare, bankrupt due, court issue, client, creditors, bankruptcy forms, money, pay, self-declared bankruptcy, bank, debt, applicant, bankruptcy judgment, dormant company
#
#
#
# Casetype: General Divorce Proceedings (588 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.07109)
# 	 - Proceedings for divorce?.
# sentence_2: (dist :0.0701)
# 	 - RE DIVORCE.
# sentence_3: (dist :0.0701)
# 	 - How can she divorce him?
# sentence_4: (dist :0.06604)
# 	 - What's the divorce proceedings?.
# sentence_5: (dist :0.06018)
# 	 - The procedures of divorce under non-consummation.. 1.
# sentence_6: (dist :0.05953)
# 	 - What are the procedures for divorce proceedings?..
# sentence_7: (dist :0.05846)
# 	 - Divorce proceedings and maintenance order proceedings.
# sentence_8: (dist :0.05639)
# 	 - The process of a divorce; 2.
# sentence_9: (dist :0.05514)
# 	 - Enquiring about divorce proceedings.
# sentence_10: (dist :0.05379)
# 	 - General divorce proceedings.
# sentence_11: (dist :0.05123)
# 	 - How to file for a divorce?
# sentence_12: (dist :0.05111)
# 	 - Whether there can be divorce proceedings or would it be nullity.
# sentence_13: (dist :0.05022)
# 	 - Can I revoke this divorce?.
# sentence_14: (dist :0.04993)
# 	 - Seeking for divorce..
# sentence_15: (dist :0.04907)
# 	 - Explanation of divorce proceedings and maintenance of child.
# sentence_16: (dist :0.04818)
# 	 - 1 ) How to proceed with the divorce..
# sentence_17: (dist :0.04706)
# 	 - Whether client should engage a lawyer for divorce proceedings?
# sentence_18: (dist :0.0456)
# 	 - Applicant wishes to know about divorce proceedings..
# sentence_19: (dist :0.04401)
# 	 - The applicant would like to know about the proceedings of divorce..
# sentence_20: (dist :0.04332)
# 	 - Husband refuses to divorce..
# sentence_21: (dist :0.04315)
# 	 - Can divorce papers be served?.
# sentence_22: (dist :0.04137)
# 	 - Divorce- further arguments..
# sentence_23: (dist :0.04042)
# 	 - Overseas marriage; divorce proceedings in Singapore.
#
# **keywords:**
# legal aid, is client, maintenance order proceedings, own flat, divorce process, lawyer, immediate divorce, proceedings, a. adultery b. separation, divorce procedure, year period, potential divorce, control, maintenance, uncontested divorce, divorce papers, applicant file, post marriage, much maintenance fees, divorce settlement period, paper order, potential child abduction, same house, wife, legal wife, possible divorce, sole custody, child custody, general divorce proceedings, divorce proceedings, divorce letter, current husband, successful divorce proceedings, good lawyer, husband, child, singapore flat, child price, applicant object, matrimonial home, divorce, assets, care, pay, local husband, legal proceeding, courts, housing issue, applicant, interim custody, a. property
#
#
#
# Casetype: Claims (Tortious) (532 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.03255)
# 	 - How can the applicant claim for his medical fees..
# sentence_2: (dist :0.0248)
# 	 - What are the next steps for the applicant?.
# sentence_3: (dist :0.02382)
# 	 - The applicant inquired about legal fees if a lawyer were to be hired.
# sentence_4: (dist :0.02119)
# 	 - Applicant feels that he should not be 100% responsible for damages.
# sentence_5: (dist :0.02109)
# 	 - Is Applicant liable to pay the $ 15,000 to the rental company..
# sentence_6: (dist :0.02104)
# 	 - What can the applicant do..
# sentence_7: (dist :0.02081)
# 	 - How should Applicant respond to the statement of claim?
# sentence_8: (dist :0.02049)
# 	 - Can the applicant return the vehicle without being sued?..
# sentence_9: (dist :0.01962)
# 	 - Applicant wants an explanation of the letter being sent..
# sentence_10: (dist :0.01959)
# 	 - Can she claim her medical fees from her ex-boyfriend?.
# sentence_11: (dist :0.01943)
# 	 - Whether the Applicant has any claims against the sub-contractor.
# sentence_12: (dist :0.01898)
# 	 - What legal recourse does the applicant have?.
# sentence_13: (dist :0.01814)
# 	 - Whether the applicant should pursue the case in the civil court.
# sentence_14: (dist :0.01788)
# 	 - Applicant wants to file a claim for the cards against the seller.
# sentence_15: (dist :0.01771)
# 	 - Can the applicant go to the small claims tribunal and sue the company Co Assets..
# sentence_16: (dist :0.01733)
# 	 - Is this a personal injury claim?.
# sentence_17: (dist :0.01709)
# 	 - Can claim against two companies?.
# sentence_18: (dist :0.01661)
# 	 - How could Applicant recover his money from B?
# sentence_19: (dist :0.01653)
# 	 - Was there defamation?..
# sentence_20: (dist :0.01649)
# 	 - Applicant wishes to sue for defamation...
# sentence_21: (dist :0.01584)
# 	 - Should applicant sign the apology letter?
# sentence_22: (dist :0.01547)
# 	 - Can the applicant sue the AP?
# sentence_23: (dist :0.01542)
# 	 - How can the applicant recover his $ 500 deposit..
# sentence_24: (dist :0.01514)
# 	 - How to claim back the $ 7,200?.
#
# **keywords:**
# other party, passengers, apology letter, law firm, same company, lawyer, medical fees, fazli claim compensation, purported accident, property damage, more money, compensation, fees, car owner, police case, damages, defamation case, applicant file, civil suit, case, app claim compensation, damage fees, future loss, court documents, claim, medical cost, is applicant, small claims tribunal, amount, applicant claim, legal fees, legal recourse does client, police, private lawyer, medical negligence, company, hospital, full amount, client, issue, payment, action, letter, neighbour liable, money, possible charges, several police reports, other guy, applicant, demands, civil action
#
#
#
# Casetype: Tenancy Disputes (456 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.02734)
# 	 - What the applicant can claim..
# sentence_2: (dist :0.02652)
# 	 - How can the applicant, the tenant, dispute this?.
# sentence_3: (dist :0.02504)
# 	 - Can they claim for more than the deposit?.
# sentence_4: (dist :0.02497)
# 	 - Landlord and tenant dispute.
# sentence_5: (dist :0.02274)
# 	 - Small claim matter.
# sentence_6: (dist :0.02225)
# 	 - The tenant claimed the defects in the Small Claims Tribunal..
# sentence_7: (dist :0.02171)
# 	 - 1. Landlord-tenant dispute-whether landlord can file a counter-claim against the tenant's claim.
# sentence_8: (dist :0.02163)
# 	 - Should Applicant file a claim against him?.
# sentence_9: (dist :0.02088)
# 	 - Can the applicant recover his rental deposit..
# sentence_10: (dist :0.02068)
# 	 - When the Applicant is allowed to evict the tenant.. Tenancy agreement.
# sentence_11: (dist :0.0202)
# 	 - Applicant would like his deposit back.
# sentence_12: (dist :0.0195)
# 	 - tenancy dispute, withholding deposit.
# sentence_13: (dist :0.01709)
# 	 - Also claim for loss of tenancy opportunity....
# sentence_14: (dist :0.01693)
# 	 - 1 ) How do I chase the tenants out now 2 ) How to claim the monthly $ 500 from Adverse Party..
# sentence_15: (dist :0.01685)
# 	 - Termination of tenancy; forfeiture of deposit.
# sentence_16: (dist :0.01685)
# 	 - Is this $ 8,000 claim by the landlord valid?
# sentence_17: (dist :0.01684)
# 	 - Whether client may be sued by the tenant for withholding $ 300 in deposit?
# sentence_18: (dist :0.01669)
# 	 - Why is he claiming $ 2,000?
#
# **keywords:**
# small claims, rental deposit, civil claim, first landlord, previous client, current landlord, small claims documents, action does client, tenancy agreement, tenants, landlord, owner, rental agreement, refund deposit, other compensation, legal action, rental income, property rights, damages, case, counter claims, first month, deposit, full deposit, new residential address, tenant dispute, contract illegal, evidences applicant, third party, main tenant, termination clause, former tenants, amount, applicant claim, outstanding rent, landlord-tenant dispute-whether landlord, previous house, court order, get liu, possible cause, security deposit, entire agreement, applicant claim damages, contract, money, rent, current tendency contract, tenancy opportunity, other tenant, applicant, court approval
#
#
#
# Casetype: Claims (Contractual) (447 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.02672)
# 	 - Whether a company can be a plaintiff in the small claims tribunal?
# sentence_2: (dist :0.026)
# 	 - Can he claim damages for this contract?
# sentence_3: (dist :0.0251)
# 	 - Can the applicant claim her money back?.
# sentence_4: (dist :0.02498)
# 	 - Will the legal fees be more than the claims.
# sentence_5: (dist :0.0232)
# 	 - Should app claim from 1st or 2nd car rental company.
# sentence_6: (dist :0.02072)
# 	 - Is the employment contract still legally enforceable.
# sentence_7: (dist :0.01958)
# 	 - To pursue small claims.
# sentence_8: (dist :0.01878)
# 	 - The customer was cheated by a questionable car company.
# sentence_9: (dist :0.01853)
# 	 - Is there any issue with the car loan?.
# sentence_10: (dist :0.01713)
# 	 - Can the applicant claim the cost of repair from AP?.
# sentence_11: (dist :0.01701)
# 	 - Is the legal document enforceable?
# sentence_12: (dist :0.01617)
# 	 - 1 ) What are the legal options and likelihood of recovering the car..
# sentence_13: (dist :0.01617)
# 	 - To sue the dealer who sold the car or the sue the company.
# sentence_14: (dist :0.01559)
# 	 - The client is seeking to claim back his $ 10,000 deposit from the bar owner. 2.
#
# **keywords:**
# employment contract, months extra pay contrary, other party, small claims, bank account, civil claim, goods, contract clause, civil case, more money, 2-year contract, relevant documents, replacement claim, car, car rental company, is ong, damages, repair costs, personal debts, insurance company, high court, legal position, deposit, sums, monthly payments, impending issues, agreement, small claims tribunal, court, amount, possible legal action, auto-renewal clause, does ms, applicant claim, contractual breach, lemon law, monetary claim, warranty claim, second hand car company, year warranty, rental fee, action, letter, money, pay, car dealers, car loan, other company, applicant, contracts, sct order
#
#
#
# Casetype: Employment (433 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.03842)
# 	 - Can the applicant terminate/breach the employment contract..
# sentence_2: (dist :0.03445)
# 	 - Whether the non-termination clause within applicant's employment contract is onerous?
# sentence_3: (dist :0.02831)
# 	 - Is there any way Applicant can claim her half-month salary from her employer?.
# sentence_4: (dist :0.02697)
# 	 - What are the applicant's options?.
# sentence_5: (dist :0.02511)
# 	 - What are the applicant's legal rights?
# sentence_6: (dist :0.02388)
# 	 - Applicant wishes to claim the money from the company..
# sentence_7: (dist :0.02384)
# 	 - Is it okay for applicant to sign..
# sentence_8: (dist :0.02369)
# 	 - Employment contract; claiming salary and annual leave owed following resignation..
# sentence_9: (dist :0.02225)
# 	 - Applicant is requesting for 1 month worth of salary for his services..
# sentence_10: (dist :0.02225)
# 	 - Whether there was a breach in the contract?
# sentence_11: (dist :0.02205)
# 	 - 1 ) Can applicant claim the goodwill payment now?.
# sentence_12: (dist :0.02197)
# 	 - Is the issue a rental or employment issue?.
# sentence_13: (dist :0.02165)
# 	 - Employment.
# sentence_14: (dist :0.02061)
# 	 - - Is the Applicant in breach of the restraint of trade clauses?.
# sentence_15: (dist :0.01838)
# 	 - Is the old contract valid?.
# sentence_16: (dist :0.01825)
# 	 - Summary termination of employment.
# sentence_17: (dist :0.01781)
# 	 - 1. Whether the contract which states that the notice period is 3 months is binding 2.
# sentence_18: (dist :0.01781)
# 	 - The applicant is concerned about the welfare of the child.
# sentence_19: (dist :0.01739)
# 	 - Employment Issues with Nityo3PSolutions.
#
# **keywords:**
# employment contract, employment issues, employment, labour court order, month compensation, singapore office, outstanding pay, civil case, compensation, months time, notice period, new action, transportation fees, employment agency, due salary, employee tribunal, time pay, party, older clients, work, ex employer, unfair dismissal, legal issue, half-month salary, month, termination clause, is applicant, way applicant, amount, overtime pay, applicant claim, company, employment claim, court order, current company, former company, employer breach, ex company, payment, salary, non-compete clause, contract, money, signed contract, termination letter, old contract, applicant, new employer, contract/tortious claim, monetary compensation, or civil claim
#
#
#
# Casetype: POHA (Protection from Harassment Act) (339 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.03617)
# 	 - Whether there is case of harassment?.
# sentence_2: (dist :0.0335)
# 	 - - Harassment.-
# sentence_3: (dist :0.0335)
# 	 - Harassment.
# sentence_4: (dist :0.0335)
# 	 - Harassment..
# sentence_5: (dist :0.03297)
# 	 - What are the steps that applicant could take to stop the harassment..
# sentence_6: (dist :0.03224)
# 	 - How could the Applicant file a protection from harassment application?.
# sentence_7: (dist :0.02999)
# 	 - Is applicant able to sue Adverse Party?
# sentence_8: (dist :0.02898)
# 	 - Applicant is also afraid of publicity.
# sentence_9: (dist :0.0289)
# 	 - Whether the applicant can apply for Protection Order for herself....
# sentence_10: (dist :0.02727)
# 	 - Protection from Harassment ( POHA ), court procedures for Protection Order....
# sentence_11: (dist :0.02555)
# 	 - Is the applicant able to clear his name?
# sentence_12: (dist :0.02491)
# 	 - Harassment, PPO; claim in criminal and civil.
# sentence_13: (dist :0.02459)
# 	 - The applicant questioned on follow up actions, especially regarding on legal actions regarding potential harassment..
# sentence_14: (dist :0.02434)
# 	 - Will Cyrus be able to haul applicant to court?..
# sentence_15: (dist :0.0242)
# 	 - Can she get an anti harassment order?
# sentence_16: (dist :0.02418)
# 	 - How can I stop this harassment? 2.
# sentence_17: (dist :0.02412)
# 	 - PPO vs Protection from Harassment Act.
# sentence_18: (dist :0.02354)
# 	 - Adverse Party is continually harassing and defaming applicant through social media..
# sentence_19: (dist :0.02243)
# 	 - What can the applicant do?....
# sentence_20: (dist :0.02223)
# 	 - Can applicant seek civil / criminal action for this matter?.....
# sentence_21: (dist :0.02122)
# 	 - Adverse Party is a public nuisance.
# sentence_22: (dist :0.02097)
# 	 - Or should they go under Protection from Harassment Act ( POHA ) instead?.
# sentence_23: (dist :0.02031)
# 	 - How does Applicant prove that the emails were sent by the ex-husband?
# sentence_24: (dist :0.02011)
# 	 - Whether client may be able to claim aggravated damages?.
#
# **keywords:**
# other party, possible monetary claim, civil claim, mr chua file poha application, is client, ppo, harassment order, other party/and other parties, matter, legal action, other ongoing ect case, address, general damages, restraint order, applicant file, text messages, family matter, order, debt recovery company, party, magistrate complaint, harassment act, protection, charges, applicants job, pdpa issues, poha states emails, third party, adverse party, multiple times, other incidents, is applicant, defamation suit, criminal action, civil matters, police, public nuisance, court procedures, harassment tactics, poha, harassment application, criminal claim, action, applicant number, last harassment, single day, applicant, alleged harassment, harassment, protection order, ongoing court case
#
#
#
# Casetype: Magistrate's Complaints & Private Summons (268 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.02725)
# 	 - What action should the applicant take?.
# sentence_2: (dist :0.02627)
# 	 - Should the applicant file a magistrate's complaint?.
# sentence_3: (dist :0.0232)
# 	 - Should the applicant lodge another police report?
# sentence_4: (dist :0.02014)
# 	 - The applicant has gone to the magistrates court.
# sentence_5: (dist :0.0197)
# 	 - How the applicant can commence proceedings against the other party..
# sentence_6: (dist :0.01866)
# 	 - - Whether the Applicant can pursue any criminal or civil claims against his wife.
# sentence_7: (dist :0.01843)
# 	 - 1 ) How to file the claims that applicant wishes to make...
# sentence_8: (dist :0.01738)
# 	 - Can Applicant sue the Adverse Party?.
# sentence_9: (dist :0.01708)
# 	 - Should applicant accept the compensation?..
# sentence_10: (dist :0.01605)
# 	 - Can the applicant claim compensation for injuries etc. via ways other than suing?
# sentence_11: (dist :0.01575)
# 	 - How can the applicant sue his neighbor.
# sentence_12: (dist :0.01494)
# 	 - Can the applicant proceed with repairs?.
# sentence_13: (dist :0.01439)
# 	 - 1. What action the applicant can take to stop the ruination of her image and her company's image..
# sentence_14: (dist :0.01389)
# 	 - Are the actions done by the harasser considered a criminal act ( criminal intimidation )?.
# sentence_15: (dist :0.01172)
# 	 - How should Applicant move forward in order to be financially compensated?
# sentence_16: (dist :0.0117)
# 	 - Can Applicant file charges against woman ( name & address unknown ).
# sentence_17: (dist :0.01168)
# 	 - Applicant enquired as to how he could represent himself in litigation..
# sentence_18: (dist :0.01127)
# 	 - 1 ) the applicant wants to obtain' justice' against the manager..
#
# **keywords:**
# other party, own proceedings, course, complaint, jurong police station, protection order, magistrate court, other people, magistrate, damages, rights do applicant, applicant file, evidence, case, satisfactory legal action, company management, ex boyfriend, magistrate complaint, person x, harassment act, calls, charges, telecoms, third party, next course, criminal act, court, alleged assault, further actions, police officer, weeks time, applicant claim, settlement, police, possible legal actions, personal claim, mental health treatment, such matters, court issue, action, applicant lodge, disciplinary action, legal cost, first police report, crime registry, applicant prepare, individual, legal actions, applicant, criminal intimidation, applicant claim compensation
#
#
#
# Casetype: Loans (260 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.0262)
# 	 - How can the applicant get his money back?.
# sentence_2: (dist :0.02558)
# 	 - Can the applicant claim lawyer fees from the other parties?.
# sentence_3: (dist :0.02278)
# 	 - Issue 1: Can the applicant claim the $ 1,500?
# sentence_4: (dist :0.02247)
# 	 - Can the applicant file for bankruptcy?.
# sentence_5: (dist :0.0222)
# 	 - Whether Applicant may be able to claim the sum of money and through which means..
# sentence_6: (dist :0.02152)
# 	 - Personal loans.
# sentence_7: (dist :0.01977)
# 	 - - Refusal by applicant's friend to repay money owed to applicant.
# sentence_8: (dist :0.01939)
# 	 - Applicant seeks to retrieve the money back from Adverse Party..
# sentence_9: (dist :0.0187)
# 	 - The applicant's niece has yet to repay the $ 7,000 loan.
# sentence_10: (dist :0.01808)
# 	 - Whether Applicant can recover the sum of $ 2000 from his colleague..
# sentence_11: (dist :0.01784)
# 	 - There is no written contract to prove that applicant loaned $ 16,500.
# sentence_12: (dist :0.01738)
# 	 - However, applicant could only prove the loan by recalling their oral contract..
# sentence_13: (dist :0.01483)
# 	 - Her legal liability to pay the debt.
# sentence_14: (dist :0.01404)
# 	 - What the applicant does about the writ of summons.
#
# **keywords:**
# legal recourse does applicant, small claims, other party, several claims, interest, client claim, previous applicant, person, legal action, friend, personal loan, small sum, handwritten letter, bank staff, applicant file, civil suit, credit card debt, party, motor company, friendly loan, legal recourse, application form, loan agreements, debt repayment scheme, adverse party, agreement, court, present cases, amount, bankruptcy status, fidrec case, bankruptcy, court order, interim order, other colleagues, best course, client, applicant claim lawyer fees, sum, unsuccessful debt collector, action, x files, contract, money, money debtor company, bank loan, debt, oral contract, applicant, valid service, physical enforcement action
#
#
#
# Casetype: Small Claims (App/Enforcement/Appeal) (245 cases)
#
# Column used: advice
# **excerpts:**
# sentence_1: (dist :0.04651)
# 	 - Whether the can enforce the order of tribunal claim..
# sentence_2: (dist :0.04585)
# 	 - 1 ) How to prepare for the small claims tribunal hearing.
# sentence_3: (dist :0.0393)
# 	 - Can she claim for the money?.
# sentence_4: (dist :0.03406)
# 	 - How the applicant can go about claiming his $ 7000..
# sentence_5: (dist :0.02881)
# 	 - Should Applicant file his claim against the company or against his boss?
# sentence_6: (dist :0.0257)
# 	 - 1 ) What is an appropriate claim amount?
# sentence_7: (dist :0.02293)
# 	 - Applicant wants to know how to enforce money order.. How to enforce the court order?.
# sentence_8: (dist :0.0227)
# 	 - Is the letter a court order?.
# sentence_9: (dist :0.02135)
# 	 - 2. Can AP conduct a civil claim, or higher legal action, against him?
# sentence_10: (dist :0.02076)
# 	 - Is Mr Ho's claim still valid?.
#
# **keywords:**
# small claims, tribunal, civil claim, lawyer, employment claims, judgment sum, entire claim, money judgement, installation company, money order, contract interpretation, divorce matter, property developer, applicant file, small, case, settlement agreement, order, issues, small claims tribunal hearing, claim, adverse party, hearing date, small claims tribunal, court, amount, tribunal order, small claim tribunals, small claims tribunal case, sct, applicant claim, other remedies, company, court order, small claims tribunal order, new claim, balance payment, ect sum, best way, payment, small cliams court, money, services, legal actions, enforcement, k kumar law practice, applicant, owners, sct order, damage cost

# %% [markdown]
# ## Synposis only

# %%
out_synopsis = {}

for casetype, num_cases in top_n_casestypes:
    print('\n\n\nCasetype: ' + 
          casetype + 
          ' (' + 
          str(num_cases) + 
          ' cases)')
    
    out_synopsis[casetype] = textrank_generate(df, 
                                               casetype, 
                                               col='synopsis', 
                                               sim_score_threshold=sim_score_threshold, 
                                               phrase_limit=phrase_limit, 
                                               word_limit=word_limit, 
                                               to_print=to_print, 
                                               to_plot=to_plot)
# Out:
# Casetype: Bankruptcy / DRS (804 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.03523)
# 	 - Bank filed bankruptcy against applicant.
# sentence_2: (dist :0.03098)
# 	 - Applicant applied for bankruptcy.
# sentence_3: (dist :0.03037)
# 	 - Banks will not file bankruptcy against him.
# sentence_4: (dist :0.02998)
# 	 - Applicant facing bankruptcy.
# sentence_5: (dist :0.02852)
# 	 - Applicant owes the bank $ 80000 in debt and wants to file for bankruptcy..
# sentence_6: (dist :0.02767)
# 	 - Applicant came from a bankruptcy hearing.
# sentence_7: (dist :0.02652)
# 	 - The applicant wants voluntarily file for bankruptcy.
# sentence_8: (dist :0.02614)
# 	 - The applicant has received a bankruptcy notice from a bank.
# sentence_9: (dist :0.02606)
# 	 - Applicant wants to self-declare bankruptcy.
# sentence_10: (dist :0.02562)
# 	 - Applicant wishes to apply for bankruptcy..
# sentence_11: (dist :0.0251)
# 	 - . Applicant wants to declare bankruptcy herself..
# sentence_12: (dist :0.02454)
# 	 - Applicant's company has filed a bankruptcy against her. Applicant's outstanding debt of $ 136000 to manulife.
# sentence_13: (dist :0.02446)
# 	 - The applicant has declared bankruptcy.
# sentence_14: (dist :0.02422)
# 	 - The applicant applied for personal insolvency ( bankruptcy ).
# sentence_15: (dist :0.02409)
# 	 - Applicant faced a bankruptcy hearing, for which she owes $ 250,000.
# sentence_16: (dist :0.02402)
# 	 - The court proceeded as the applicant himself applied for bankruptcy, not the creditor..
# sentence_17: (dist :0.02367)
# 	 - The applicant has not attended any bankruptcy hearings..
# sentence_18: (dist :0.02349)
# 	 - Applicant owe the banks around $ 92,000.
# sentence_19: (dist :0.02342)
# 	 - . Applicant wants to resist the bankruptcy application.
# sentence_20: (dist :0.02314)
# 	 - Applicant had his first bankruptcy court hearing today.
# sentence_21: (dist :0.02304)
# 	 - Applicant is facing a bankruptcy claim against him.
# sentence_22: (dist :0.02295)
# 	 - Applicant has outstanding debts with 7 other banks as well.
# sentence_23: (dist :0.02295)
# 	 - Applicant has incurred a debt of approximately $ 80,000.. Applicant is filing for bankruptcy.
# sentence_24: (dist :0.02291)
# 	 - BC bank applied for statutory bankruptcy.
# sentence_25: (dist :0.02284)
# 	 - Bankruptcy matter.
# sentence_26: (dist :0.0227)
# 	 - Applicant is now applying to be discharged from bankruptcy.
# sentence_27: (dist :0.02245)
# 	 - Applicant's is considering filing for bankruptcy.
# sentence_28: (dist :0.02244)
# 	 - Applicant is thinking of self-declared bankruptcy.
# sentence_29: (dist :0.02242)
# 	 - The applicant came in for a potential bankruptcy advice.
# sentence_30: (dist :0.02222)
# 	 - Total debt owed by Applicant: About $ 160K. Total creditors: about 10 banks.
# sentence_31: (dist :0.02199)
# 	 - Applicant is unsure of bankruptcy proceedings.
# sentence_32: (dist :0.02192)
# 	 - Applicant has debts in various banks amounting to over $ 40,000..
# sentence_33: (dist :0.02168)
# 	 - The applicant's loan amounts to $ 80,000..
# sentence_34: (dist :0.02167)
# 	 - Applicant is applying for a voluntary bankruptcy.
# sentence_35: (dist :0.02149)
# 	 - Applicant owes $ 80,000-$90,000 of debt
# sentence_36: (dist :0.02135)
# 	 - The applicant is a retiree and is now filing for a bankruptcy..
# sentence_37: (dist :0.02128)
# 	 - The applicant is being sued by a vehicle leasing company for bankruptcy.
# sentence_38: (dist :0.0212)
# 	 - Likely to be bankruptcy, if BC bank knows that 50% of Applicant's assets can satisfy debt.
# sentence_39: (dist :0.0212)
# 	 - Also, Applicant to be aware of restrictions upon bankruptcy.
# sentence_40: (dist :0.02105)
# 	 - The applicant was discharged from his first bankruptcy 8 years ago.
# sentence_41: (dist :0.02094)
# 	 - CIMB has sued applicant for bankruptcy..
# sentence_42: (dist :0.0208)
# 	 - The bankruptcy proceedings commenced then.
# sentence_43: (dist :0.02071)
# 	 - Now he faces bankruptcy proceedings.
# sentence_44: (dist :0.02052)
# 	 - Applicant owes a few banks money.
# sentence_45: (dist :0.02041)
# 	 - Bankruptcy by CD bank took priority of that.
# sentence_46: (dist :0.02036)
# 	 - Applicant only carried out the bankruptcy proceedings upon recovering from the stroke.
# sentence_47: (dist :0.02016)
# 	 - Applicant applied for bankruptcy in 2010 and was made a bankrupt in 2011.
#
# **keywords:**
# other banks, different banks, applicant ’s bank account, application, bankrupt, personal bankruptcy, personal liability issue, taxi technology companies, file, ongoing business, bankruptcy charge, international bank, high court, hearing, approached applicant, purchase order, debt repayment scheme, loan agreement, bankruptcy proceedings, constant debt, round applicant, current pay, small claims tribunal, bankruptcy application, applicant, applicant claim, month bond, amounts, immediate bankrupt status, bankruptcy, loan, company, repayment scheme, banks, self-declared bankrupt, bankruptcy forms, outstanding debts, payment, creditors, sum, other vendors, money, pay, applicant business, company stamp, debt, simple loan agreement, applicant money, credit counselling seminar, state courts, bankruptcy case
#
#
#
# Casetype: General Divorce Proceedings (588 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.03927)
# 	 - The applicant's husband is divorcing her.
# sentence_2: (dist :0.03381)
# 	 - Husband and applicant are still marries and not divorced.
# sentence_3: (dist :0.03321)
# 	 - - The applicant's husband has filed for divorce.
# sentence_4: (dist :0.03315)
# 	 - A has been divorced before..
# sentence_5: (dist :0.03266)
# 	 - Husband is asking for divorce..
# sentence_6: (dist :0.0324)
# 	 - The applicant is involved in divorce proceedings.
# sentence_7: (dist :0.03189)
# 	 - The applicant was divorced from December 2005.
# sentence_8: (dist :0.03159)
# 	 - The applicant had a divorce case 10 years ago.
# sentence_9: (dist :0.03157)
# 	 - Applicant wants to divorce his wife of three years.
# sentence_10: (dist :0.0297)
# 	 - This is a mutual divorce.
# sentence_11: (dist :0.02956)
# 	 - Applicant has 3 children with her husband.
# sentence_12: (dist :0.0295)
# 	 - However, after the divorce, there was a child born in Singapore and out-of-wedlock.
# sentence_13: (dist :0.02921)
# 	 - Wife is threatening divorce.
# sentence_14: (dist :0.02885)
# 	 - The applicant divorce proceedings commenced against her.
# sentence_15: (dist :0.02879)
# 	 - Their children are 23, 24 and 28 years old.
# sentence_16: (dist :0.02873)
# 	 - . Applicant wants to divorce.
# sentence_17: (dist :0.0285)
# 	 - The applicant has 2 children ( 2 and 4 years old ).
# sentence_18: (dist :0.02838)
# 	 - Applicant currently underdoing divorce proceedings.
# sentence_19: (dist :0.02823)
# 	 - Client has divorced with the husband.
# sentence_20: (dist :0.02805)
# 	 - A is unemployed and divorced.
# sentence_21: (dist :0.02777)
# 	 - Applicant has been served divorce papers by wife.
#
# **keywords:**
# singapore citizen, year marriage, singapore pr, june/july applicant, have file, lawyer, been problems, divorce judgement, husband asap, divorce wife, children, divorce procedure, child everyday, wife claims, maintenance fee, years old, marriage-the applicant, child maintenance costs, case file, rental house, uncontested divorce, issues, year stage, wife, divorce documents, thai husband, teh custody, year old boy, divorce proceedings, year old son, divorce case, husband pr status, husband, applicant filing, have conflict, court order, divorce, husband cane, blackmail applicant, young children, client, care, children products, money, pay, former husband, daughter, matrimonial flat, applicant, second wife, mutual divorce
#
#
#
# Casetype: Claims (Tortious) (532 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.01725)
# 	 - The applicant however wants to claim $ 5000..
# sentence_2: (dist :0.01678)
# 	 - There is a claim against the applicant.
# sentence_3: (dist :0.01617)
# 	 - Applicant has reported to the police.
# sentence_4: (dist :0.01565)
# 	 - Applicant worked for a company, and had an accident.
# sentence_5: (dist :0.01499)
# 	 - Applicant has filed a counter claim.
# sentence_6: (dist :0.0146)
# 	 - Right now the applicant owes around $ 200,000 to the company.
# sentence_7: (dist :0.01449)
# 	 - Due to an accident, Applicant claimed there was no severe damaged to the rented car..
# sentence_8: (dist :0.01444)
# 	 - Applicant had psychiatrist report and medical report.
# sentence_9: (dist :0.01433)
# 	 - Applicant has filed a police report...
# sentence_10: (dist :0.01416)
# 	 - Applicant has only two days left to file a valid claim.
# sentence_11: (dist :0.01364)
# 	 - The applicant seeks a motorcycle insurance claim.
# sentence_12: (dist :0.01355)
# 	 - Boss claims that ID has not paid them and so the applicant has to pay him.
# sentence_13: (dist :0.01333)
# 	 - Taxi driver claims that applicant has hit him.
# sentence_14: (dist :0.01327)
# 	 - Applicant paid a $ 20 000 deposit to the company and then $ 75 000.
# sentence_15: (dist :0.01322)
# 	 - A debt recovering company has issued a letter to recover a debt of around $ 2000 from the applicant.
# sentence_16: (dist :0.01299)
# 	 - Applicant brought a case against an on-line service company.
# sentence_17: (dist :0.01271)
# 	 - Applicant already has another partner..
# sentence_18: (dist :0.01268)
# 	 - Car rental company is claiming $ 15,000 from Applicant in third-party insurance charges due to a traffic accident.
# sentence_19: (dist :0.01245)
# 	 - Applicant lent him some money ( $ 80 ) first.
# sentence_20: (dist :0.01237)
# 	 - In 2015, the applicant lodged a police report..
# sentence_21: (dist :0.01214)
# 	 - Insurance company repudiates liability because applicant did not report the accident and any potential claim.
# sentence_22: (dist :0.01212)
# 	 - Applicant has a small company and has an issue with Data Register.
# sentence_23: (dist :0.01193)
# 	 - Applicant filed an application to the small claims tribunal.
# sentence_24: (dist :0.01192)
# 	 - The applicant claimed that he merely took photos of his surrounding.
# sentence_25: (dist :0.01175)
# 	 - The applicant had signed the contract with singtel signed in 2015.
# sentence_26: (dist :0.01172)
# 	 - Insurance company refused to indemnify applicant.
# sentence_27: (dist :0.01171)
# 	 - The applicant then sent his car for repairs.
# sentence_28: (dist :0.01147)
# 	 - Applicant was involved in a car accident.
# sentence_29: (dist :0.01125)
# 	 - Applicant screamed.
# sentence_30: (dist :0.01125)
# 	 - Applicant is a Grab driver and company assesses the car..
# sentence_31: (dist :0.01112)
# 	 - Applicant has not received any machinery.
# sentence_32: (dist :0.01105)
# 	 - Applicant has been defamed.
#
# **keywords:**
# store said warranty, small claims, additional money, other party, transport claims, lawyer, posb account, son, years old, police report, car, cheating case, injury claim, applicant claims, additional work, insurance company, car acccident, subscription fee, outstanding payments, have judgment, damaging applicant, file claim, applicant sign, client claims, damage claims, medical letter, friends, court, amount, khoo teck phuat hospital, contract information, videoing applicant, company name, promised return, police, company, state active active, car accident, insurance claim, client, service provider, money, medical reports, accident applicant, july applicant, daughter, legal questions/ issues, same day, applicant, 3rd day applicant, mr
#
#
#
# Casetype: Tenancy Disputes (456 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.0283)
# 	 - Applicant is the landlord of a tenant.
# sentence_2: (dist :0.02631)
# 	 - The applicant has been to the small claims court.
# sentence_3: (dist :0.026)
# 	 - - Applicants have been renting flat for last 5 years.- 1 month of rental
# sentence_4: (dist :0.02548)
# 	 - Applicant's tenancy agreement is for 12 months and has been stamped.
# sentence_5: (dist :0.02546)
# 	 - The Applicant was a tenant, and wishes to claim his deposit from his landlord.
# sentence_6: (dist :0.02546)
# 	 - Applicant is a tenant.
# sentence_7: (dist :0.02546)
# 	 - - Applicant is tenant.
# sentence_8: (dist :0.02501)
# 	 - The applicant had a tenancy agreement dispute with landlord.
# sentence_9: (dist :0.02464)
# 	 - Tenant is not paying rent to the applicant..
# sentence_10: (dist :0.02431)
# 	 - applicant is the landlord ( there are 2 landlords ).
# sentence_11: (dist :0.0242)
# 	 - The applicant's tenant was paid $ 1200 of deposit when they signed the agreement.
# sentence_12: (dist :0.02358)
# 	 - Applicant is the tenant's agent.
# sentence_13: (dist :0.02326)
# 	 - The applicant has paid 2 months' rental as security deposit.
# sentence_14: (dist :0.02272)
# 	 - Applicant has tenancy issue with her landlord.
# sentence_15: (dist :0.02221)
# 	 - The applicant is facing the tenancy disputes with her tenant.
# sentence_16: (dist :0.0222)
# 	 - The rental amount per month is $ 1000.. The Applicant rented a room.
# sentence_17: (dist :0.02202)
# 	 - Applicant's house is a rented house.
# sentence_18: (dist :0.02184)
# 	 - This is the tenant's last month.
# sentence_19: (dist :0.02175)
# 	 - Applicant tenanted an apartment.
# sentence_20: (dist :0.02173)
# 	 - Applicant signed a tenancy agreement for 2 years.
# sentence_21: (dist :0.02165)
# 	 - Deposit is for 2 months.
# sentence_22: (dist :0.02165)
# 	 - Deposit $ 2600 is 1 month.
# sentence_23: (dist :0.02156)
# 	 - Landlord has refused to pay.. Tenant 1: Applicant has a tenant.
# sentence_24: (dist :0.02154)
# 	 - Applicant had to resign from the job 5 months into the tenancy agreement.
# sentence_25: (dist :0.02151)
# 	 - The two tenancy agreements were for two years each..
#
# **keywords:**
# tenant, house, rental deposit, move, initial tenancy agreement, ex tenants, damage, month deposit, landlord, tenancy agreement, owner, applicant cheques, other tenants, small claims tribunal summons, left windows, last year, months, first month rent, property agent, been court orders, bedroom apartment, applicant name, deposit, tenant company, minimum stay, pilipino rents, return, applicant tenancy agreement, remaining months, agreement, small claim tribunals, marisley pay, applicants unit, occupants had spoilt, female landlord, have lift, paid rent, security deposit, client, contract, new landlord, pay, house owner, rent, actual landlord, notice, applicants reminders, applicant, living room, several other tenants, additional year had provisions
#
#
#
# Casetype: Claims (Contractual) (447 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.03283)
# 	 - The applicant rented a car from a rental company.
# sentence_2: (dist :0.032)
# 	 - The applicant has since returned the car to the company..
# sentence_3: (dist :0.02735)
# 	 - Car rental company now wants to claim damages.
# sentence_4: (dist :0.02606)
# 	 - Bluesg electric car rental company.
# sentence_5: (dist :0.02559)
# 	 - Applicant bought a car.
# sentence_6: (dist :0.025)
# 	 - Car Cove Leasing Company claimed against him.
# sentence_7: (dist :0.02482)
# 	 - Applicant signed a contract with the company for 1 year.
# sentence_8: (dist :0.02482)
# 	 - She owned a second hand car.
# sentence_9: (dist :0.02321)
# 	 - Applicant works at a car workshop.
# sentence_10: (dist :0.02239)
# 	 - The applicant wished to buy a car.
# sentence_11: (dist :0.02224)
# 	 - 9 year old vehicle Applicant no longer has the car with him.
# sentence_12: (dist :0.02104)
# 	 - Dispute regarding a car rental contract.
# sentence_13: (dist :0.02104)
# 	 - The applicant's company owes her some money under her agreement.
# sentence_14: (dist :0.02099)
# 	 - Applicant bought a Volkswagen car 2 years ago.
# sentence_15: (dist :0.02098)
# 	 - - The payment to the car company by him through her ( credit card and cheque worth of $ 20k.
# sentence_16: (dist :0.02042)
# 	 - Dispute with car dealer.
# sentence_17: (dist :0.02008)
# 	 - the car dealer has not signed it..
#
# **keywords:**
# monthly pay, other party, golden charter company, bought car, sg car mart, months contract, company account, car, replacement claim, first payment, car rental payment, applicant money, repair costs, have daylight, said person, case, blank sales agreement, former client, applicant vehicle, other companies, new car, car radiator, work, rental costs, applicant giro, renewal fee, car dealer, applicants wife, agreement, second hand car, amount, common sign, dollars deposit, time applicant, sales contract, company, monetary claim, new contract, car rental contract, contractor, issue, client, payment, letter, contract, money, pay, company resolution, year, applicant, vehicle stability light
#
#
#
# Casetype: Employment (433 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.02963)
# 	 - The applicant is currently still working in the company.
# sentence_2: (dist :0.02924)
# 	 - Applicant left the company.
# sentence_3: (dist :0.02826)
# 	 - Filed claim against his company for not paying his salary for four months.
# sentence_4: (dist :0.02705)
# 	 - He signed an Employment Contract (' the Contract' ) with the previous Company that he was working for (' the Employer' ).
# sentence_5: (dist :0.02689)
# 	 - The applicant worked at a company, RE&S, for 3 years.
# sentence_6: (dist :0.02609)
# 	 - Usually company will pay within 5 working days ( commission to her ).
# sentence_7: (dist :0.02476)
# 	 - Company say will arrange for 1 month salary.
# sentence_8: (dist :0.02471)
# 	 - She claims that the company owes her $ 8000 for two months ( $ 4k per month ).
# sentence_9: (dist :0.02417)
# 	 - The applicant worked 4 months in a company as an operation manager earning $ 1,600/month.
# sentence_10: (dist :0.0237)
# 	 - The company did not pay her at all.
# sentence_11: (dist :0.02358)
# 	 - Have a contract signed with the previous company.
# sentence_12: (dist :0.02335)
# 	 - Terminated by company.
# sentence_13: (dist :0.02292)
# 	 - The applicant wishes to retire from a company.
# sentence_14: (dist :0.02187)
# 	 - Applicant allegedly gave company 30 days notice prior to leaving.
# sentence_15: (dist :0.02147)
# 	 - Previously was paid $ 8665/month.. Employment Contract for 3 months.
# sentence_16: (dist :0.02036)
# 	 - Applicant's salary is $ 13,000 per month..
# sentence_17: (dist :0.01976)
# 	 - She has a previous claim against a company, however, the company she has claimed against has already wound up.
#
# **keywords:**
# job scope, gardening leave, state compensation, salary dispute, months, employment act, notice period, work date, previous company, applicant money, last month, other logistics companies, applicant claims, uncompleted period, uncompleted contract period, last day, amount applicant, claims, work, new employer, terminated employees, termination clause, ntuc work, salary issue, small claims tribunal, current pay, company owner, mom website, overtime pay, years, receive pay, service provider company, sign, term contract, company, current company, months salary, applicant estimates, client, salary, letter, upfront payment, contract, electrical works, pay, similar issue, employment claims tribunals, notice, applicant, old company, previous employer
#
#
#
# Casetype: POHA (Protection from Harassment Act) (339 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.02012)
# 	 - Applicant called the police.
# sentence_2: (dist :0.01943)
# 	 - The applicant is a harassment case.
# sentence_3: (dist :0.01886)
# 	 - Applicant made a police report.
# sentence_4: (dist :0.01871)
# 	 - The applicant thus obliged.
# sentence_5: (dist :0.01733)
# 	 - Tenant sued the applicant for harassment.
# sentence_6: (dist :0.01683)
# 	 - Applicant is here regarding harassment.
# sentence_7: (dist :0.01655)
# 	 - Police advised Applicant with POHA..
# sentence_8: (dist :0.0164)
# 	 - Applicant works for UBER.
# sentence_9: (dist :0.01597)
# 	 - The applicant came from POHA.
# sentence_10: (dist :0.01554)
# 	 - Applicant hence did not pay.
# sentence_11: (dist :0.0154)
# 	 - Applicant wishes to file a harassment case on his neighbor.
# sentence_12: (dist :0.01525)
# 	 - The applicant is the director of the company.
# sentence_13: (dist :0.01511)
# 	 - He claims that the applicant must pay for whatever damages claimed.
# sentence_14: (dist :0.01502)
# 	 - The applicant had been reported by the police to be responsible for harassment.
# sentence_15: (dist :0.0149)
# 	 - Applicant is now suspended by his company.
# sentence_16: (dist :0.01489)
# 	 - Some time in 2008, the applicant obtained PR.
# sentence_17: (dist :0.01461)
# 	 - The Applicant tendered a resignation subsequently.
# sentence_18: (dist :0.01447)
# 	 - The applicant does not live with her.
# sentence_19: (dist :0.01443)
# 	 - Applicant stopped working at that security company..
# sentence_20: (dist :0.01421)
# 	 - Applicant is being harassed.
# sentence_21: (dist :0.01421)
# 	 - applicant was harassed.
# sentence_22: (dist :0.01413)
# 	 - Applicant's deposit of $ 1000 is still with them.
# sentence_23: (dist :0.01409)
# 	 - - However, the Adverse Party then messaged the applicant later that night.
# sentence_24: (dist :0.01362)
# 	 - One of applicant worker filed employment claim.
# sentence_25: (dist :0.01362)
# 	 - Applicant is being physically and verbally attacked by her neighbour.
# sentence_26: (dist :0.01355)
# 	 - Applicant received an anonymous call.
# sentence_27: (dist :0.01351)
# 	 - The applicant and her sister were business partners.
# sentence_28: (dist :0.01344)
# 	 - The man still continues to harass the applicant.
# sentence_29: (dist :0.01344)
# 	 - Applicant's friend was his girlfriend.
# sentence_30: (dist :0.01343)
# 	 - Applicant received a harassment on Facebook messenger, from Adverse Party.
# sentence_31: (dist :0.01343)
# 	 - They even sent debt collectors to applicant's house.
# sentence_32: (dist :0.01335)
# 	 - Worker of applicant had overstayed.
# sentence_33: (dist :0.01329)
# 	 - Applicant recieved money from company X ( approx $ 300,000 ) out of goodwill.
# sentence_34: (dist :0.01329)
# 	 - He also claims that' he knows how to find [ the applicant's ] house'.
# sentence_35: (dist :0.01328)
# 	 - The applicant was working with a construction company for 11 years.
# sentence_36: (dist :0.01327)
# 	 - Friend claims that applicant cheated her money and posted their dispute online.
# sentence_37: (dist :0.01326)
# 	 - The applicant's house was reconstructed.
# sentence_38: (dist :0.01325)
# 	 - Directed CCTV at applicant's home 2.
# sentence_39: (dist :0.01324)
# 	 - Applicant is faced with claims from debt collectors.
# sentence_40: (dist :0.01314)
# 	 - the applicant is the plaintiff, and brought his neighbor for harassment.
# sentence_41: (dist :0.01309)
# 	 - Unfortunately, the applicant's father threw the letter away accidentally.
# sentence_42: (dist :0.013)
# 	 - Applicant filed for divorce with her husband last year.
# sentence_43: (dist :0.013)
# 	 - * Note: Subsequently, the applicant conversed in Tamil.
# sentence_44: (dist :0.01289)
# 	 - In 2016, the lady lodged a police report alleging that applicant harassed her.
# sentence_45: (dist :0.01284)
# 	 - Applicant has gone to PTPC.
# sentence_46: (dist :0.01283)
# 	 - Applicant deleted her online accounts.
# sentence_47: (dist :0.01281)
# 	 - Ex-boyfriend has recently slapped applicant.
# sentence_48: (dist :0.0127)
# 	 - Applicant has been in pain.
# sentence_49: (dist :0.01261)
# 	 - Applicant is pursuing a harassment claim against her former employer.
# sentence_50: (dist :0.01257)
# 	 - Applicant supplier of Chinese medicine.
# sentence_51: (dist :0.01249)
# 	 - ( 4 ) The applicant was recommended to PJP..
# sentence_52: (dist :0.01247)
# 	 - Applicant has no peace of mind at all.
# sentence_53: (dist :0.01245)
# 	 - The applicant have 2 children, aged 17 and 20.
# sentence_54: (dist :0.01239)
# 	 - Applicant had a Burmese maid.
# sentence_55: (dist :0.01238)
# 	 - The Applicant then blocked the GM's contact number.
# sentence_56: (dist :0.01233)
# 	 - The applicant previously obtained a PPO against another family member..
# sentence_57: (dist :0.0123)
# 	 - Applicant wishes to sue three individuals for sexual harassment.
# sentence_58: (dist :0.01225)
# 	 - Applicant says this is an PTPC issue.
# sentence_59: (dist :0.01223)
# 	 - The applicant and her boyfriend got together in 2014 and split up in 2015.
#
# **keywords:**
# house, lodged police reports, applicants husband, time, messages, file, police report, several threatening messages, mental condition client, case, applicant sister, other illegal activities, debt recovery company, mobile number, harassment act, disparaging facebook posts, pictures, adverse party, report, other family members, friends, a insulated applicant, debt collectors, husband, past few years, police, anonymous call, applicant supplier, company, child, injunction order, applicant yesterday, edith money, applicant drop, applicants door, applicant worker, health issues, client, photos, formal claim, money, pay, videos, statutory claims, daughter, applicant, alleged harassment, applicant messages, harassment, applicant names, maid work
#
#
#
# Casetype: Magistrate's Complaints & Private Summons (268 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.02702)
# 	 - applicant also has a police report.
# sentence_2: (dist :0.02437)
# 	 - Applicant owes $ 20,000.
# sentence_3: (dist :0.02387)
# 	 - Applicants have reported this to the police and have filed with the magistrate..
# sentence_4: (dist :0.02267)
# 	 - Applicant has his medical reports..
# sentence_5: (dist :0.02178)
# 	 - Applicant visited his house once to deliver the police report.
# sentence_6: (dist :0.02128)
# 	 - Applicant wants to file a magistrate's complaint.
# sentence_7: (dist :0.02077)
# 	 - The applicant has filed a magistrate complaint.
# sentence_8: (dist :0.0204)
# 	 - Applicant wants to sue him.
# sentence_9: (dist :0.01965)
# 	 - Applicant had a girlfriend in 2005.
# sentence_10: (dist :0.01899)
# 	 - Applicants found out where she lived.
# sentence_11: (dist :0.01855)
# 	 - The applicant can also speak Vietnamese.
# sentence_12: (dist :0.01807)
# 	 - The applicants were also fined..
# sentence_13: (dist :0.01798)
# 	 - The applicant's property has been seized by the police.
# sentence_14: (dist :0.01788)
# 	 - The applicant attended 2 sessions of mediations.
# sentence_15: (dist :0.01746)
# 	 - Applicant has a case with MOM
# sentence_16: (dist :0.01717)
# 	 - They interviewed the applicant regarding his issue.
# sentence_17: (dist :0.01707)
# 	 - Resident scolded applicant a' Dog' Applicant made a police report.
# sentence_18: (dist :0.01704)
# 	 - the worker walked away, but the applicant kept walking.
# sentence_19: (dist :0.01697)
# 	 - The harasser is actually one of the applicant's friends.
# sentence_20: (dist :0.01675)
# 	 - The applicant lodged a police report against his worker's boyfriend, because his worker's boyfriend threatened him.
# sentence_21: (dist :0.01669)
# 	 - Every month, applicant was paid back $ 1,500.
# sentence_22: (dist :0.01639)
# 	 - The applicant is working at a polyclinic.
# sentence_23: (dist :0.01628)
# 	 - The applicant and her boyfriend are no longer in contact..
# sentence_24: (dist :0.01618)
# 	 - BIL and the applicant then broke into a fight.
# sentence_25: (dist :0.01616)
# 	 - Filed police report.
# sentence_26: (dist :0.01597)
# 	 - The applicant is living alone with her mother.
# sentence_27: (dist :0.01581)
# 	 - Applicant wishes to file claims against him on all three charges..
# sentence_28: (dist :0.0158)
# 	 - Applicant has documents from the Hospital.
# sentence_29: (dist :0.01564)
# 	 - Applicant has photo and cctv evidence.
# sentence_30: (dist :0.01539)
# 	 - Applicant was bullied (? ) by his friends.
# sentence_31: (dist :0.01538)
# 	 - The applicant was assaulted in school by his classmate.
# sentence_32: (dist :0.01534)
# 	 - The applicant wishes to pursue the action due the insincerity of the other party and the subsequent actions of the other party..
# sentence_33: (dist :0.01534)
# 	 - Applicant was assaulted at her workplace, Kopitiam.
# sentence_34: (dist :0.01523)
# 	 - To withdraw Adverse Party's complaint, Applicant has to withdraw all her complaints.
# sentence_35: (dist :0.01506)
# 	 - - Applicant has complained to the MPs.
# sentence_36: (dist :0.01492)
# 	 - Applicant has never talked to Adverse Party about these..
# sentence_37: (dist :0.01487)
# 	 - Applicant wishes to demand for reasonable compensation.
# sentence_38: (dist :0.0148)
# 	 - The applicant owns a shop, where his worker works.
#
# **keywords:**
# other party, second time, house, magistrates, applicant niece, damage, magistrate complaint form, complaint, dog, lawyer, sufficient evidence, attack applicant, charge, phone call, grievous injuries, medical report, letter boxes, matter, police reports, car, use, case, wife, other documentation, first applicant, claims, policeman applicant, applicant son, work, psychological issues, parties, report, central police division, magistrate complain, subsequent actions, court, police officer, mediation hearing, incident, time applicant, assault case, employment applicant, police, assault, days mc, client, applicant family, neighborhood police station, applicant, piece, second applicant
#
#
#
# Casetype: Loans (260 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.03477)
# 	 - Total money loaned was $ 4000.
# sentence_2: (dist :0.03194)
# 	 - The loan was repaid.
# sentence_3: (dist :0.03049)
# 	 - - AP loaned money ( $ 1,300 ) from the applicant.
# sentence_4: (dist :0.02779)
# 	 - The applicant loaned money to a friend ( ex- colleague ) but the friend is not at his home.
# sentence_5: (dist :0.0264)
# 	 - This is a personal loan.
# sentence_6: (dist :0.02632)
# 	 - Applicant owes 3 bank loans from credit cards.
# sentence_7: (dist :0.02469)
# 	 - Applicant loaned his ex- girlfriend some money, around $ 170,000 in May 2014.
# sentence_8: (dist :0.02429)
# 	 - Applicant loaned money to another party-$ 11,500 ( cash ) 8 months ago.
# sentence_9: (dist :0.0239)
# 	 - The applicant facing issue with 20 years bank Loan.
# sentence_10: (dist :0.0239)
# 	 - The money is for investment.
# sentence_11: (dist :0.0238)
# 	 - On 23 March, a portion of loan was repaid.
# sentence_12: (dist :0.02324)
# 	 - The applicant transferred a loan of money of ( $ 80,000, with $ 4,000 in May 2017 ) to someone between July-Nov 2017.
# sentence_13: (dist :0.02172)
# 	 - Loan amount balance is around $ 7,100.
# sentence_14: (dist :0.0208)
# 	 - Loans were given to his company.
# sentence_15: (dist :0.02075)
# 	 - Client owed a bank a sum of money.
# sentence_16: (dist :0.02066)
# 	 - The applicant has been approached by this company to repay the sum.
# sentence_17: (dist :0.02058)
# 	 - Applicant is a divorcee.
# sentence_18: (dist :0.02053)
# 	 - In total, applicant gave his friend a total of $ 23,380.
# sentence_19: (dist :0.01978)
# 	 - He has been two months since he had loaned the amount.
# sentence_20: (dist :0.01961)
# 	 - Applicant was physically harmed by a friend ( Adverse Party ).
# sentence_21: (dist :0.01958)
# 	 - Applicant lend his friend $ 500.
# sentence_22: (dist :0.01941)
# 	 - The last loan was given in 2012..
# sentence_23: (dist :0.0191)
# 	 - All transfer of money is documented..
#
# **keywords:**
# other party, small claims, interest, several sums, singapore dollars, time, last year, friend, was supposed repay, assault applicant, individual money, personal loan, police report, minimum payment, credit card problem, applicant money, money issue, return money, someone money, credit card debt, work permit officer, returns, many years, other people money, friendly loan, payments, adverse party, parties, agreement, december applicant, taiwanese friend, month period, private company, applicants father, long-time friend, renovation loan, ex company, client, letter, applicants uncle, money, partial amount, bank loan, total money, taiwanese bank account, bank, loan repayment, year, applicant, bank money, applicant interest
#
#
#
# Casetype: Small Claims (App/Enforcement/Appeal) (245 cases)
#
# Column used: synopsis
# **excerpts:**
# sentence_1: (dist :0.03215)
# 	 - Applicant filed a small claims against a company.
# sentence_2: (dist :0.03116)
# 	 - Small claims Tribunal.
# sentence_3: (dist :0.02753)
# 	 - The applicant had to claim for this $ 11k through small claims tribunal.
# sentence_4: (dist :0.02703)
# 	 - Small claims tribunal held in favor of the company..
# sentence_5: (dist :0.0249)
# 	 - However, 1k was paid by applicant's company and 50 from the applicant herself.
# sentence_6: (dist :0.02487)
# 	 - Applicant represents her company.
# sentence_7: (dist :0.02137)
# 	 - Small claim of $ 1270 for salary.
# sentence_8: (dist :0.02042)
# 	 - The applicant has had a small tribunals court case previously.
# sentence_9: (dist :0.0199)
# 	 - Enforceability of court order from Small Claims Tribunal..
# sentence_10: (dist :0.01971)
# 	 - Contract with Colorado, small claims case.
# sentence_11: (dist :0.01941)
# 	 - Other party is a construction company, likely a small time one..
# sentence_12: (dist :0.0193)
# 	 - The applicant runs an interior design works company.
# sentence_13: (dist :0.01926)
# 	 - The dispute is between the applicant and the manager of the company.
# sentence_14: (dist :0.01903)
# 	 - On 24 March, the client came to small claims tribunal.
# sentence_15: (dist :0.0181)
# 	 - The applicant has received employment claims from a Private Limited Company.
# sentence_16: (dist :0.01776)
# 	 - The applicant wishes to claim unused prepaid medicure (? ) packages from a company.
# sentence_17: (dist :0.01771)
# 	 - Applicant emailed the company who agreed to reschedule.
# sentence_18: (dist :0.01706)
# 	 - Court ordered for contractor to pay Applicant by 9 May 2018.-
# sentence_19: (dist :0.01697)
# 	 - The Applicant owes a credit card company a sum of money.
#
# **keywords:**
# small claims, small time, interior design company, small claims order, months extension, renovation contract, motorbike deposit, private contractors, similar claim, applicants stance, money order, general marketing work, other reports, small, settlement agreement, insurance company, respondent, applicant use water, new car, claim, construction company, payments, sure applicants, small claims tribunal, final payment, car company, years warranty issue, overtime pay, applicant, company name, small tribunals case, company respondent, years warranty, company, court order, renovation work, contractor, issue, client, full maintenance fees, sum, contractor-contractor say, contract, pay, sct claim amount, new mcsts, applicant monies, birthday party services, property search record, applicant money

# %% [markdown]
# ## Both Advice and Synopsis

# %%
out_both = {}

for casetype, num_cases in top_n_casestypes:
    print('\n\n\nCasetype: ' + 
          casetype + 
          ' (' + 
          str(num_cases) + 
          ' cases)')
    
    out_both[casetype] = textrank_generate(df, 
                                           casetype, 
                                           col='both', 
                                           sim_score_threshold=sim_score_threshold, 
                                           phrase_limit=phrase_limit, 
                                           word_limit=word_limit, 
                                           to_print=to_print, 
                                           to_plot=to_plot)
# Out:
# Casetype: Bankruptcy / DRS (804 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03857)
# 	 - Bank filed bankruptcy against applicant.
# sentence_2: (dist :0.03802)
# 	 - Should the applicant file for bankruptcy himself?
# sentence_3: (dist :0.03442)
# 	 - Applicant applied for bankruptcy.
# sentence_4: (dist :0.03429)
# 	 - Can the applicant self-declare bankruptcy instead.
# sentence_5: (dist :0.03381)
# 	 - Banks will not file bankruptcy against him.
# sentence_6: (dist :0.0334)
# 	 - Applicant facing bankruptcy.
# sentence_7: (dist :0.03187)
# 	 - Applicant wants to file for bankruptcy.
# sentence_8: (dist :0.03068)
# 	 - Applicant owes the bank $ 80000 in debt and wants to file for bankruptcy..
# sentence_9: (dist :0.03014)
# 	 - How to avoid bankruptcy from the bank?.
# sentence_10: (dist :0.03)
# 	 - How to file a bankruptcy application?
# sentence_11: (dist :0.02989)
# 	 - Applicant came from a bankruptcy hearing.
# sentence_12: (dist :0.02896)
# 	 - The applicant now wishes to apply for bankruptcy..
# sentence_13: (dist :0.02891)
# 	 - ( 5 ) When can Applicant be discharged from bankruptcy?.
# sentence_14: (dist :0.02844)
# 	 - . Applicant wants to declare bankruptcy herself..
# sentence_15: (dist :0.02787)
# 	 - The applicant has declared bankruptcy.
# sentence_16: (dist :0.02758)
# 	 - The court proceeded as the applicant himself applied for bankruptcy, not the creditor..
# sentence_17: (dist :0.02757)
# 	 - A bank has filed a bankruptcy application to make the applicant a bankrupt.
# sentence_18: (dist :0.02754)
# 	 - How can applicant annul his bankruptcy status?.
# sentence_19: (dist :0.02748)
# 	 - Can the debt collectors bring bankruptcy actions against the applicant?
# sentence_20: (dist :0.02726)
# 	 - Applicant's company has filed a bankruptcy against her. Applicant's outstanding debt of $ 136000 to manulife.
# sentence_21: (dist :0.02722)
# 	 - Applicant's is considering filing for bankruptcy.
# sentence_22: (dist :0.02697)
# 	 - The Applicant received a Bankruptcy Order from the Court on 28 Dec 2017.
# sentence_23: (dist :0.02686)
# 	 - The applicant would like a bankruptcy protection..
# sentence_24: (dist :0.02659)
# 	 - Applicant wants to resist the bankruptcy application.
# sentence_25: (dist :0.02632)
# 	 - Bankruptcy matter.
# sentence_26: (dist :0.02632)
# 	 - Applicant has incurred a debt of approximately $ 80,000.. Applicant is filing for bankruptcy.
# sentence_27: (dist :0.02601)
# 	 - Applicant faced a bankruptcy hearing, for which she owes $ 250,000.
# sentence_28: (dist :0.02594)
# 	 - The applicant is a retiree and is now filing for a bankruptcy..
# sentence_29: (dist :0.02593)
# 	 - Applicant is facing a bankruptcy claim against him.
# sentence_30: (dist :0.02592)
# 	 - Applicant would like to self declare bankruptcy..
# sentence_31: (dist :0.02588)
# 	 - The applicant has not attended any bankruptcy hearings..
# sentence_32: (dist :0.02586)
# 	 - Applicant had his first bankruptcy court hearing today.
# sentence_33: (dist :0.02578)
# 	 - Applicant is now applying to be discharged from bankruptcy.
# sentence_34: (dist :0.02549)
# 	 - The applicant applied for personal insolvency ( bankruptcy ).
# sentence_35: (dist :0.02541)
# 	 - The bank is suing her for bankruptcy.
# sentence_36: (dist :0.02507)
# 	 - The applicant came in for a potential bankruptcy advice.
# sentence_37: (dist :0.02495)
# 	 - Applicant is unsure of bankruptcy proceedings.
# sentence_38: (dist :0.0246)
# 	 - Filling up of bankruptcy application form.
# sentence_39: (dist :0.02459)
# 	 - Applicant has outstanding debts with 7 other banks as well.
# sentence_40: (dist :0.02454)
# 	 - Now he faces bankruptcy proceedings.
# sentence_41: (dist :0.02453)
# 	 - The bankruptcy proceedings commenced then.
# sentence_42: (dist :0.02449)
# 	 - Applicant is applying for a voluntary bankruptcy.
# sentence_43: (dist :0.02422)
# 	 - BC bank applied for statutory bankruptcy.
# sentence_44: (dist :0.02421)
# 	 - Applicant here wishes to file for an appeal against a court ruling for bankruptcy.
# sentence_45: (dist :0.02402)
# 	 - Also, Applicant to be aware of restrictions upon bankruptcy.
# sentence_46: (dist :0.02385)
# 	 - Applicant was sued by a moneylender for bankruptcy.
# sentence_47: (dist :0.0238)
# 	 - Whether Applicant should sell the house or to declare for bankruptcy.
# sentence_48: (dist :0.02371)
# 	 - The applicant was discharged from his first bankruptcy 8 years ago.
#
# **keywords:**
# other banks, applicant counter, self-declared bankruptcy process, bankrupt, proper payment, other outstanding debts, debt restructuring scheme, bankrupt person, bankruptcy application forms, applicant money, applicant file, judgment sums, bankruptcy suit, sole-proprietorship business, approached applicant, false company, debt repayment scheme, applicant self, bankruptcy proceedings, first bankruptcy court hearing, other bank accounts, impending bankrupt person, current pay, client file, round applicant, bankruptcy application, housing loans, mr tiong fill, debt collectors, bankruptcy claim, banking loans, amounts, applicant self-file, mothers property, credit card companies, court order, banks, declare, bankrupt due, court issue, creditors, bankruptcy action, money, pay, credit counselling, debt, few months, simple loan agreement, applicant, bankruptcy judgment, dormant company
#
#
#
# Casetype: General Divorce Proceedings (588 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.04402)
# 	 - The applicant's husband is divorcing her.
# sentence_2: (dist :0.04133)
# 	 - What's the divorce proceedings?.
# sentence_3: (dist :0.03948)
# 	 - Client is involved in a divorce with his wife.
# sentence_4: (dist :0.03858)
# 	 - The client is divorced as of 6 October 2016.
# sentence_5: (dist :0.03826)
# 	 - Husband and applicant are still marries and not divorced.
# sentence_6: (dist :0.03803)
# 	 - A has been divorced before..
# sentence_7: (dist :0.03783)
# 	 - Whether there are any procedures for a divorce?
# sentence_8: (dist :0.03761)
# 	 - The applicant was divorced from December 2005.
# sentence_9: (dist :0.03743)
# 	 - Husband is asking for divorce..
# sentence_10: (dist :0.03729)
# 	 - RE DIVORCE.
# sentence_11: (dist :0.03729)
# 	 - How can she divorce him?
# sentence_12: (dist :0.03679)
# 	 - This is a divorce issue.
# sentence_13: (dist :0.0365)
# 	 - The applicant is planning for divorce.
# sentence_14: (dist :0.03601)
# 	 - ( 3 ) Whether the applicant can ask for maintenance from her husband if she were to divorce him...
# sentence_15: (dist :0.03574)
# 	 - Proceedings for divorce?.
# sentence_16: (dist :0.03476)
# 	 - Applicant's wife filed for divorce in 2015.
# sentence_17: (dist :0.03469)
# 	 - A is unemployed and divorced.
# sentence_18: (dist :0.0346)
# 	 - Wife is threatening divorce.
# sentence_19: (dist :0.03348)
# 	 - Client has two children, one is below 21 and one is above 21.
# sentence_20: (dist :0.03288)
# 	 - Client wishes to divorce her husband.
# sentence_21: (dist :0.03278)
# 	 - 1 ) Is the client able to commence divorce proceedings as a non-Singaporean?
# sentence_22: (dist :0.03273)
# 	 - . Applicant wants to divorce.
#
# **keywords:**
# is client, maintenance order proceedings, have file, divorce process, been problems, own flat, lawyer, immediate divorce, divorce letters, children, divorce procedure, potential divorce, singapore, years old, uncontested divorce, applicant file, post marriage, paper order, potential child abduction, same house, wife, legal wife, possible divorce, applicant wife, wife remarries, child custody, year divorce requirement, divorce proceedings, applicant commence, current husband, court, husband pr status, husband, singapore flat, have conflict, child price, applicant object, individual file, divorce, husband cane, client, care, money, pay, local husband, daughter, housing issue, applicant, legal proceedings, interim custody, year period
#
#
#
# Casetype: Claims (Tortious) (532 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03706)
# 	 - There is a claim against the applicant.
# sentence_2: (dist :0.03062)
# 	 - The Applicant was the driver.
# sentence_3: (dist :0.03017)
# 	 - The applicant was beaten up.
# sentence_4: (dist :0.02989)
# 	 - Applicant was sexually assaulted in 2016.
# sentence_5: (dist :0.02747)
# 	 - The applicant is emotionally distressed..
# sentence_6: (dist :0.02712)
# 	 - Applicant has been defamed.
# sentence_7: (dist :0.02705)
# 	 - The money that the applicant lost is $ 750.
# sentence_8: (dist :0.02635)
# 	 - Their client is applicant's competitor.
# sentence_9: (dist :0.02595)
# 	 - Can the applicant claim for damages?..
# sentence_10: (dist :0.02579)
# 	 - The applicant's car was damaged in an accident.
# sentence_11: (dist :0.02556)
# 	 - Applicant's daughter was 18 at the time.
# sentence_12: (dist :0.02504)
# 	 - Applicant is 22 years old.
# sentence_13: (dist :0.02475)
# 	 - Applicant claims the accident was n't his fault.
# sentence_14: (dist :0.02473)
# 	 - Applicant is based in India.
# sentence_15: (dist :0.0245)
# 	 - The applicant is currently under S-Pass and under investigation for over-staying.
# sentence_16: (dist :0.02441)
# 	 - What are the next steps for the applicant?.
# sentence_17: (dist :0.02413)
# 	 - Applicant is an employee of Uber.
# sentence_18: (dist :0.02406)
# 	 - Applicant was assaulted by her partner.
# sentence_19: (dist :0.02398)
# 	 - The applicant however wants to claim $ 5000..
# sentence_20: (dist :0.02384)
# 	 - Applicant is Malaysian, June.
# sentence_21: (dist :0.02378)
# 	 - Applicant has been beaten by a party.
# sentence_22: (dist :0.02375)
# 	 - The bills are under the applicant's name.
# sentence_23: (dist :0.02346)
# 	 - No charges were made against Applicant.
# sentence_24: (dist :0.0231)
# 	 - Applicant was eating steak.
# sentence_25: (dist :0.02305)
# 	 - Applicant is a home tutor.
# sentence_26: (dist :0.0228)
# 	 - The gold was snatched from the applicant.
# sentence_27: (dist :0.02274)
# 	 - The applicant was punched in the chest twice.
# sentence_28: (dist :0.02264)
# 	 - Applicant was previously a Grab car driver.
# sentence_29: (dist :0.02255)
# 	 - Applicant says there was no contract signed..
# sentence_30: (dist :0.02232)
# 	 - These were used to solicit money from the applicant..
# sentence_31: (dist :0.02228)
# 	 - Applicant has been out of a job for 7 months..
# sentence_32: (dist :0.02203)
# 	 - Applicant registered for a course which was no longer available.
# sentence_33: (dist :0.02194)
# 	 - The signed contract is not returned to the applicant.
# sentence_34: (dist :0.02189)
# 	 - Applicant was afraid and was referred here by the police.
# sentence_35: (dist :0.02187)
# 	 - Applicant has not been there longer than 26 weeks.
# sentence_36: (dist :0.02185)
# 	 - However, the applicant's address had been changed.
# sentence_37: (dist :0.02153)
# 	 - What can the applicant do..
# sentence_38: (dist :0.02137)
# 	 - Applicant has reported to the police.
# sentence_39: (dist :0.02128)
# 	 - Applicant is thinking of claiming for compensation, and has filed a police report.
# sentence_40: (dist :0.02123)
# 	 - Applicant is in an ongoing court case.
# sentence_41: (dist :0.02112)
# 	 - Applicant was served a notice for defamation.
# sentence_42: (dist :0.0211)
# 	 - Applicant is chinese and her husband is singaporean.
# sentence_43: (dist :0.02088)
# 	 - Is Applicant liable to pay the $ 15,000 to the rental company..
# sentence_44: (dist :0.02087)
# 	 - Can the applicant return the vehicle without being sued?..
# sentence_45: (dist :0.02086)
# 	 - Applicant was cheated during an investment scam.
# sentence_46: (dist :0.02077)
# 	 - Applicant suspect they are victims of a scam.
# sentence_47: (dist :0.02065)
# 	 - Applicant screamed.
# sentence_48: (dist :0.02063)
# 	 - The applicant was illegally working in Singapore for the sum.
# sentence_49: (dist :0.02048)
# 	 - ( Applicant and his father are suing his mother ).
# sentence_50: (dist :0.02046)
# 	 - Applicant has filed a counter claim.
# sentence_51: (dist :0.02043)
# 	 - Applicant feels that he should not be 100% responsible for damages.
# sentence_52: (dist :0.02028)
# 	 - Applicant lent him some money ( $ 80 ) first.
# sentence_53: (dist :0.02012)
# 	 - The company is a family business, and the applicant is representing her family.
# sentence_54: (dist :0.02009)
# 	 - Applicant filed a police report.
# sentence_55: (dist :0.01996)
# 	 - Applicant stays alone and is not married.
# sentence_56: (dist :0.01983)
# 	 - However the applicant was suspicious on authenticity of the item.
# sentence_57: (dist :0.01982)
# 	 - Applicant had a girlfriend who was overseas three years ago.
# sentence_58: (dist :0.01977)
# 	 - Applicant is being accused of theft through deceit.
# sentence_59: (dist :0.01961)
# 	 - Applicant feels that this is shameful and unreasonable..
# sentence_60: (dist :0.01959)
# 	 - Afraid of being sued, Applicant has paid the $ 1.9k..
# sentence_61: (dist :0.01947)
# 	 - Applicant already has another partner..
#
# **keywords:**
# store said warranty, other party, substandard renovation work, same company, lawyer, medical fees, fazli claim compensation, purported accident, more money, own personal account, years old, possible actions applicant, singapore police force, car owner, car, police case, damages, defamation case, applicant file, applicant claims, company co assets, app claim compensation, damage fees, court documents, younger son, claim, have judgment, applicant sign, report, work day, is applicant, friends, legal fees, promised return, legal recourse does client, police, company, small claims tribunals, hospital, full amount, client, issue, payment, letter, money, several police reports, other guy, july applicant, applicant, 3rd day applicant, mr
#
#
#
# Casetype: Tenancy Disputes (456 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.02724)
# 	 - Applicant is the landlord of a tenant.
# sentence_2: (dist :0.0271)
# 	 - The applicant has been to the small claims court.
# sentence_3: (dist :0.02694)
# 	 - The Applicant was a tenant, and wishes to claim his deposit from his landlord.
# sentence_4: (dist :0.02513)
# 	 - The applicant had a tenancy agreement dispute with landlord.
# sentence_5: (dist :0.02509)
# 	 - Applicant is a tenant.
# sentence_6: (dist :0.02509)
# 	 - - Applicant is tenant.
# sentence_7: (dist :0.02475)
# 	 - How can the applicant, the tenant, dispute this?.
# sentence_8: (dist :0.02427)
# 	 - The applicant's tenant was paid $ 1200 of deposit when they signed the agreement.
# sentence_9: (dist :0.02408)
# 	 - Tenant is not paying rent to the applicant..
# sentence_10: (dist :0.02384)
# 	 - Applicant's tenancy agreement is for 12 months and has been stamped.
# sentence_11: (dist :0.02336)
# 	 - The applicant is facing the tenancy disputes with her tenant.
# sentence_12: (dist :0.02333)
# 	 - - Applicants have been renting flat for last 5 years.- 1 month of rental
# sentence_13: (dist :0.02287)
# 	 - Applicant is the tenant's agent.
# sentence_14: (dist :0.02282)
# 	 - applicant is the landlord ( there are 2 landlords ).
# sentence_15: (dist :0.02276)
# 	 - Applicant wishes to claim $ 4000 from her tenant.
# sentence_16: (dist :0.02202)
# 	 - Landlord and tenant dispute.
# sentence_17: (dist :0.02199)
# 	 - What claims do the landlord have against the Applicant?
# sentence_18: (dist :0.02169)
# 	 - Applicant did not receive rental deposit from the tenant 2 months ago.
# sentence_19: (dist :0.02163)
# 	 - Applicant tenanted an apartment.
# sentence_20: (dist :0.02141)
# 	 - Applicant has tenancy issue with her landlord.
# sentence_21: (dist :0.02116)
# 	 - Tenancy dispute, between tenants, sublet tenants are claiming for refund of rental deposit.
# sentence_22: (dist :0.021)
# 	 - Applicant's house is a rented house.
# sentence_23: (dist :0.02095)
# 	 - Landlord has refused to pay.. Tenant 1: Applicant has a tenant.
# sentence_24: (dist :0.02086)
# 	 - The applicant disputes these claims.. 1.
# sentence_25: (dist :0.02077)
# 	 - Applicant signed a tenancy agreement for 2 years.
# sentence_26: (dist :0.02066)
# 	 - The two tenancy agreements were for two years each..
#
# **keywords:**
# tenant, small claims, move, apartment owner, civil claim, house, rental deposit, damage, first landlord, previous client, current landlord, action does client, tenancy agreement, landlord, owner, rental agreement, other tenants, left windows, rental income, room, property rights, been court orders, first month, full deposit, deposit, whole year, tenant dispute, evidences applicant, return, minimal stay period, main tenant, propnex agent, month notice, marisley pay, applicant claim, outstanding rent, occupants had spoilt, landlord-tenant dispute-whether landlord, previous house, have lift, paid rent, security deposit, entire agreement, applicant claim damages, rent, current tendency contract, former tenant, tenancy opportunity, applicant charge, applicant, additional year had provisions
#
#
#
# Casetype: Claims (Contractual) (447 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03338)
# 	 - The applicant rented a car from a rental company.
# sentence_2: (dist :0.03336)
# 	 - The car was left with the applicant's company for around 6 months.
# sentence_3: (dist :0.02888)
# 	 - Car rental company now wants to claim damages.
# sentence_4: (dist :0.02653)
# 	 - Bluesg electric car rental company.
# sentence_5: (dist :0.02587)
# 	 - Car Cove Leasing Company claimed against him.
# sentence_6: (dist :0.02558)
# 	 - The customer was cheated by a questionable car company.
# sentence_7: (dist :0.02543)
# 	 - Should app claim from 1st or 2nd car rental company.
# sentence_8: (dist :0.02513)
# 	 - Applicant signed a contract with the company for 1 year.
# sentence_9: (dist :0.02457)
# 	 - Applicant was a consultant for a SG company.
# sentence_10: (dist :0.02447)
# 	 - This company is still running.
# sentence_11: (dist :0.02417)
# 	 - Ong claims that this is not fair.
# sentence_12: (dist :0.02405)
# 	 - To sue the dealer who sold the car or the sue the company.
# sentence_13: (dist :0.02385)
# 	 - The company said that the applicant breached the contract.
# sentence_14: (dist :0.02375)
# 	 - $ 700,000 ), and this sum was paid to the company.
# sentence_15: (dist :0.02332)
# 	 - Is there any issue with the car loan?.
# sentence_16: (dist :0.02318)
# 	 - Car deposit itself was $ 10,000.
# sentence_17: (dist :0.0226)
# 	 - The applicant are facing charges from car renting company due to outstanding amount owed.
# sentence_18: (dist :0.02247)
# 	 - Applicant bought a car.
# sentence_19: (dist :0.02212)
# 	 - He is afraid to rent a car from another company because he is unsure if his rental contract allows him to do so.
#
# **keywords:**
# employment contract, months extra pay contrary, monthly pay, other party, bought car, civil case, 2-year contract, oral agreement, car, replacement claim, car rental company, is ong, applicant claims, repair costs, have daylight, said person, former client, insurance company, 2nd car rental company, deposit, applicant vehicle, other companies, early termination fee, car dealer, monthly payments, applicant giro, impending issues, applicants wife, agreement, amount, court, common sign, does ms, time applicant, faulty car, monetary claim, warranty claim, company, second hand car company, year warranty, rental fee, client, letter, contract, money, pay, car loan, unsatisfactory work, month notice stipulation, applicant, vehicle stability light
#
#
#
# Casetype: Employment (433 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.04182)
# 	 - The applicant is currently still working in the company.
# sentence_2: (dist :0.03488)
# 	 - Applicant's salary is $ 13,000 per month..
# sentence_3: (dist :0.03469)
# 	 - Applicant left the company.
# sentence_4: (dist :0.03228)
# 	 - There is no employment contract between the applicant and her employer.
# sentence_5: (dist :0.03186)
# 	 - Applicant filed a claim against the company.
# sentence_6: (dist :0.0316)
# 	 - The applicant's company is a sub-contractor of a project.
# sentence_7: (dist :0.0311)
# 	 - Applicant was not paid his salary for the last month..
# sentence_8: (dist :0.02976)
# 	 - The applicant worked at a company, RE&S, for 3 years.
# sentence_9: (dist :0.02952)
# 	 - The applicant is paid $ 12 an hour.
# sentence_10: (dist :0.02928)
# 	 - - A letter that the applicant sent to the company was returned to the applicant.
# sentence_11: (dist :0.02842)
# 	 - Applicant is here with queries about his salary.
# sentence_12: (dist :0.02818)
# 	 - He signed an Employment Contract (' the Contract' ) with the previous Company that he was working for (' the Employer' ).
# sentence_13: (dist :0.02815)
# 	 - Applicant is making a claim against the company for failing to pay for overtime
# sentence_14: (dist :0.02803)
# 	 - Applicant is seeking to claim $ 434.99.
# sentence_15: (dist :0.02786)
# 	 - What are the applicant's options?.
# sentence_16: (dist :0.02774)
# 	 - the applicant was not willing.
# sentence_17: (dist :0.02733)
# 	 - Whether the non-termination clause within applicant's employment contract is onerous?
# sentence_18: (dist :0.02717)
# 	 - Previously was paid $ 8665/month.. Employment Contract for 3 months.
# sentence_19: (dist :0.02696)
# 	 - The applicant believes that she has been wrongfully terminated by her company.
# sentence_20: (dist :0.02689)
# 	 - Applicant is a recruiter.
# sentence_21: (dist :0.02632)
# 	 - Applicant is here as regards an employment issue.
# sentence_22: (dist :0.02627)
# 	 - Applicant's girlfriend is leaving the company due to stress.
# sentence_23: (dist :0.02602)
# 	 - Applicant's signed an employment contract with an employment agency.
# sentence_24: (dist :0.02562)
# 	 - - applicant.
# sentence_25: (dist :0.02551)
# 	 - The applicant worked 4 months in a company as an operation manager earning $ 1,600/month.
# sentence_26: (dist :0.0251)
# 	 - Is it okay for applicant to sign..
# sentence_27: (dist :0.02487)
# 	 - Applicant is working in Malaysia around 180 days.
#
# **keywords:**
# employment contract, work history, unused leave, company fire, month compensation, mom complaint, outstanding pay, civil case, months, months time, notice period, employment agency, due salary, applicant claims, job agency, time pay, older clients, last day, amount applicant, work, ex employer, legal issue, half-month salary, terminated employees, termination clause, is applicant, way applicant, overtime pay, company letter, company, employment claim, current company, former company, long years, work appraisal, ex company, work injury compensation act, 1-month notice, payment, salary, non-compete clause, letter, contract, money, pay, signed contract, company lawyer, termination letter, applicant, new employer, or civil claim
#
#
#
# Casetype: POHA (Protection from Harassment Act) (339 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03971)
# 	 - Applicant is a PR.
# sentence_2: (dist :0.0395)
# 	 - The applicant is a harassment case.
# sentence_3: (dist :0.03846)
# 	 - Applicant's deposit of $ 1000 is still with them.
# sentence_4: (dist :0.03792)
# 	 - Applicant is here regarding harassment.
# sentence_5: (dist :0.03748)
# 	 - applicant was harassed.
# sentence_6: (dist :0.0336)
# 	 - Applicant is being physically and verbally attacked by her neighbour.
# sentence_7: (dist :0.03309)
# 	 - Applicant's friend was his girlfriend.
# sentence_8: (dist :0.03252)
# 	 - Applicant is now suspended by his company.
# sentence_9: (dist :0.03234)
# 	 - The applicant is the director of the company.
# sentence_10: (dist :0.0323)
# 	 - The applicant's house was reconstructed.
# sentence_11: (dist :0.03208)
# 	 - Previously, the applicant was a AIA agent.
# sentence_12: (dist :0.03202)
# 	 - Applicant has been in pain.
# sentence_13: (dist :0.03183)
# 	 - Applicant believes that she is mentally unstable.
# sentence_14: (dist :0.0316)
# 	 - Applicant was bankrupt in 2005, and was recharged in 2012.
# sentence_15: (dist :0.03154)
# 	 - ( 4 ) The applicant was recommended to PJP..
# sentence_16: (dist :0.03018)
# 	 - Applicant declined to be interviewed.
# sentence_17: (dist :0.02922)
# 	 - The applicant and her sister were business partners.
# sentence_18: (dist :0.02908)
# 	 - Applicant says this is an PTPC issue.
# sentence_19: (dist :0.02893)
# 	 - The Applicant has a pool of clients who have been supporting her.
# sentence_20: (dist :0.02893)
# 	 - Applicant is facing a neighbour dispute since 2005.
# sentence_21: (dist :0.02793)
# 	 - The applicant's boyfriend is still married with children.
# sentence_22: (dist :0.0277)
# 	 - Adverse Party is harassing Applicant.
# sentence_23: (dist :0.02756)
# 	 - Applicant has been receiving threats from them.
# sentence_24: (dist :0.02747)
# 	 - Applicant is faced with claims from debt collectors.
# sentence_25: (dist :0.02737)
# 	 - Applicant thinks that the people are related by police.
# sentence_26: (dist :0.02728)
# 	 - the applicant is the plaintiff, and brought his neighbor for harassment.
# sentence_27: (dist :0.02724)
# 	 - - There has been no physical assault on the applicant.
# sentence_28: (dist :0.02697)
# 	 - Is the applicant able to clear his name?
# sentence_29: (dist :0.02667)
# 	 - Applicant says that the pictures are not hers and are not of her either
# sentence_30: (dist :0.02654)
# 	 - Applicant was advised to file a magistrate's complaint..
# sentence_31: (dist :0.02653)
# 	 - The applicant thus obliged.
# sentence_32: (dist :0.02651)
# 	 - What can the applicant do?.
# sentence_33: (dist :0.02646)
# 	 - The applicant is being harassed by an unknown person.
# sentence_34: (dist :0.02633)
# 	 - What are the steps that applicant could take to stop the harassment..
# sentence_35: (dist :0.02608)
# 	 - Applicant alleges that neighbour is harassing him.
# sentence_36: (dist :0.02588)
# 	 - Applicant called the police.
# sentence_37: (dist :0.02572)
# 	 - The Applicant is the' god-sister' to Tan's husband..
# sentence_38: (dist :0.0257)
# 	 - The applicant has been harassed by three schoolmates.
# sentence_39: (dist :0.0255)
# 	 - Harassment message received by the applicant states that it was issued from the state court.
# sentence_40: (dist :0.02546)
# 	 - Applicant is pursuing a harassment claim against her former employer.
# sentence_41: (dist :0.02542)
# 	 - Applicant is a property manager at a condominium.
# sentence_42: (dist :0.02522)
# 	 - Applicant was unable to reach an agreement even after mediation.
# sentence_43: (dist :0.02499)
# 	 - The applicant was working with a construction company for 11 years.
# sentence_44: (dist :0.02476)
# 	 - Is applicant able to sue Adverse Party?
# sentence_45: (dist :0.02461)
# 	 - - Applicant was locked in the room from 5- 8/9 pm 3.
# sentence_46: (dist :0.02424)
# 	 - Tenant sued the applicant for harassment.
# sentence_47: (dist :0.02413)
# 	 - Applicant was being harrassed and has filed a police report.
# sentence_48: (dist :0.02377)
# 	 - The applicant has been bullied and harassed.
# sentence_49: (dist :0.02363)
# 	 - The applicant is being referred to as mentally unsound etc.
# sentence_50: (dist :0.02343)
# 	 - Applicant's daughter was also threatened with physical violence.
# sentence_51: (dist :0.02315)
# 	 - Will Cyrus be able to haul applicant to court?..
# sentence_52: (dist :0.02297)
# 	 - The applicant came from POHA.
# sentence_53: (dist :0.02263)
# 	 - Applicant works for UBER.
# sentence_54: (dist :0.02241)
# 	 - Applicant being harassed by lady 12 years older than him.
#
# **keywords:**
# house, applicant counter, possible monetary claim, civil claim, lim motors/the debt collection company, is client, harassment order, medical report, several threatening messages, police report, other ongoing ect case, applicant file, text messages, applicant sister, debt recovery company, malay family, purported police personnel, harassment act, pdpa issues, disparaging facebook posts, applicants job, possible money laundering attempt, parties, other incidents, multiple times, report, adverse party, is applicant, friends, a insulated applicant, husband, past few years, police, anonymous call, child, applicant dispute, court procedures, applicant drop, photos, client, applicant number, money, pay, videos, daughter, legal actions, applicant, alleged harassment, harassment, protection order, maid work
#
#
#
# Casetype: Magistrate's Complaints & Private Summons (268 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03142)
# 	 - Should the applicant lodge another police report?
# sentence_2: (dist :0.02947)
# 	 - Should the applicant file a magistrate's complaint?.
# sentence_3: (dist :0.02866)
# 	 - Applicant made police report.
# sentence_4: (dist :0.02825)
# 	 - Applicants have reported this to the police and have filed with the magistrate..
# sentence_5: (dist :0.02762)
# 	 - Applicant has filed for a police report.
# sentence_6: (dist :0.02655)
# 	 - Applicant owes $ 20,000.
# sentence_7: (dist :0.02581)
# 	 - Applicant lodged a personal magistrate's complaint.
# sentence_8: (dist :0.02547)
# 	 - What action should the applicant take?.
# sentence_9: (dist :0.0235)
# 	 - Applicant visited his house once to deliver the police report.
# sentence_10: (dist :0.02336)
# 	 - Should applicant accept the compensation?..
# sentence_11: (dist :0.02203)
# 	 - Applicant has his medical reports..
# sentence_12: (dist :0.02193)
# 	 - Applicant wants to sue him.
# sentence_13: (dist :0.02175)
# 	 - How can the applicant appeal to the Supreme Court?
# sentence_14: (dist :0.02144)
# 	 - Applicant wishes to file claims against him on all three charges..
# sentence_15: (dist :0.02141)
# 	 - Applicant had a girlfriend in 2005.
# sentence_16: (dist :0.02082)
# 	 - Applicants found out where she lived.
# sentence_17: (dist :0.02045)
# 	 - Can the applicant proceed with repairs?.
# sentence_18: (dist :0.02038)
# 	 - The applicant lodged a police report against his worker's boyfriend, because his worker's boyfriend threatened him.
# sentence_19: (dist :0.02037)
# 	 - 1 ) How to file the claims that applicant wishes to make...
# sentence_20: (dist :0.02029)
# 	 - The applicant can also speak Vietnamese.
# sentence_21: (dist :0.0202)
# 	 - How the applicant can commence proceedings against the other party..
# sentence_22: (dist :0.01991)
# 	 - Can Applicant sue the Adverse Party?.
# sentence_23: (dist :0.01975)
# 	 - The applicants were also fined..
# sentence_24: (dist :0.01972)
# 	 - The applicant's property has been seized by the police.
# sentence_25: (dist :0.01948)
# 	 - The applicant attended 2 sessions of mediations.
# sentence_26: (dist :0.0194)
# 	 - They interviewed the applicant regarding his issue.
# sentence_27: (dist :0.01885)
# 	 - Resident scolded applicant a' Dog' Applicant made a police report.
# sentence_28: (dist :0.01867)
# 	 - Applicant has a case with MOM
# sentence_29: (dist :0.0186)
# 	 - the worker walked away, but the applicant kept walking.
# sentence_30: (dist :0.01853)
# 	 - The harasser is actually one of the applicant's friends.
# sentence_31: (dist :0.01831)
# 	 - Can the applicant claim compensation for injuries etc. via ways other than suing?
# sentence_32: (dist :0.01828)
# 	 - Every month, applicant was paid back $ 1,500.
# sentence_33: (dist :0.01774)
# 	 - The applicant and her boyfriend are no longer in contact..
# sentence_34: (dist :0.01767)
# 	 - The applicant is living alone with her mother.
# sentence_35: (dist :0.01762)
# 	 - BIL and the applicant then broke into a fight.
# sentence_36: (dist :0.0175)
# 	 - The applicant is working at a polyclinic.
# sentence_37: (dist :0.0173)
# 	 - The applicants has already filed skeletal arguments etc.
# sentence_38: (dist :0.01727)
# 	 - Applicant has documents from the Hospital.
#
# **keywords:**
# other party, house, mediation, magistrates, applicant niece, damage, complaint, jurong police station, charge, magistrate court, grievous injuries, medical report, letter boxes, other people, car, rights do applicant, applicant file, evidence, case, dog abuse, satisfactory legal action, wife, magistrate complaint, calls, work, policeman applicant, third party, applicant appeal, alleged assault, police officer, applicant claim, applicant file charges, incident, weeks time, police, personal claim, such matters, client, court issue, magistrate report, action, applicant lodge, legal cost, first police report, neighborhood police station, applicant prepare, applicant, applicant request, second issue, piece, applicant claim compensation
#
#
#
# Casetype: Loans (260 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03121)
# 	 - Total money loaned was $ 4000.
# sentence_2: (dist :0.0312)
# 	 - - AP loaned money ( $ 1,300 ) from the applicant.
# sentence_3: (dist :0.03118)
# 	 - The loan was repaid.
# sentence_4: (dist :0.02755)
# 	 - The applicant loaned money to a friend ( ex- colleague ) but the friend is not at his home.
# sentence_5: (dist :0.0258)
# 	 - - Refusal by applicant's friend to repay money owed to applicant.
# sentence_6: (dist :0.02556)
# 	 - This is a personal loan.
# sentence_7: (dist :0.02497)
# 	 - Applicant owes 3 bank loans from credit cards.
# sentence_8: (dist :0.02479)
# 	 - Applicant loaned his ex- girlfriend some money, around $ 170,000 in May 2014.
# sentence_9: (dist :0.02466)
# 	 - Applicant loaned money to another party-$ 11,500 ( cash ) 8 months ago.
# sentence_10: (dist :0.02441)
# 	 - The money is for investment.
# sentence_11: (dist :0.02408)
# 	 - Whether Applicant may be able to claim the sum of money and through which means..
# sentence_12: (dist :0.02394)
# 	 - The applicant facing issue with 20 years bank Loan.
# sentence_13: (dist :0.02358)
# 	 - The applicant transferred a loan of money of ( $ 80,000, with $ 4,000 in May 2017 ) to someone between July-Nov 2017.
# sentence_14: (dist :0.02322)
# 	 - On 23 March, a portion of loan was repaid.
# sentence_15: (dist :0.02265)
# 	 - Personal loans.
# sentence_16: (dist :0.02225)
# 	 - The applicant has been approached by this company to repay the sum.
# sentence_17: (dist :0.02181)
# 	 - Client owed a bank a sum of money.
# sentence_18: (dist :0.02126)
# 	 - Loans were given to his company.
# sentence_19: (dist :0.02123)
# 	 - She wants the money to be returned to her..
# sentence_20: (dist :0.02116)
# 	 - There is no written contract to prove that applicant loaned $ 16,500.
# sentence_21: (dist :0.02083)
# 	 - Loan amount balance is around $ 7,100.
# sentence_22: (dist :0.02062)
# 	 - Applicant is a divorcee.
#
# **keywords:**
# legal recourse does applicant, other party, small claims, interest, previous applicant, friend, was supposed repay, years old, assault applicant, individual money, personal loan, small sum, bank staff, police report, minimum payment, money issue, handwritten letter, applicant file, return money, someone money, credit card debt, other people money, motor company, friendly loan, debt repayment scheme, loan agreement, parties, adverse party, housing loan problems, amount, present cases, taiwanese friend, december applicant, month period, court, long-time friend, client, applicant claim lawyer fees, sum, singapore airlines, money, money debtor company, bank loan, total money, bank, debt, partial payment, applicant, bank money, physical enforcement action, applicant interest
#
#
#
# Casetype: Small Claims (App/Enforcement/Appeal) (245 cases)
#
# Columns used: advice and synopsis
# **excerpts:**
# sentence_1: (dist :0.03537)
# 	 - Applicant filed a small claims against a company.
# sentence_2: (dist :0.03266)
# 	 - Small claims Tribunal.
# sentence_3: (dist :0.02925)
# 	 - The applicant had to claim for this $ 11k through small claims tribunal.
# sentence_4: (dist :0.02785)
# 	 - Should Applicant file his claim against the company or against his boss?
# sentence_5: (dist :0.02733)
# 	 - Small claims tribunal held in favor of the company..
# sentence_6: (dist :0.02657)
# 	 - How can applicant make an appeal to small claims tribunal?.
# sentence_7: (dist :0.0247)
# 	 - Small claim of $ 1270 for salary.
# sentence_8: (dist :0.02409)
# 	 - Applicant represents her company.
# sentence_9: (dist :0.02391)
# 	 - However, 1k was paid by applicant's company and 50 from the applicant herself.
# sentence_10: (dist :0.02369)
# 	 - Whether the can enforce the order of tribunal claim..
# sentence_11: (dist :0.02367)
# 	 - Applicant claimed that an court order was made already..
# sentence_12: (dist :0.02114)
# 	 - Contract with Colorado, small claims case.
# sentence_13: (dist :0.02082)
# 	 - Enforceability of court order from Small Claims Tribunal..
# sentence_14: (dist :0.02041)
# 	 - On 24 March, the client came to small claims tribunal.
# sentence_15: (dist :0.02011)
# 	 - The applicant wishes to claim unused prepaid medicure (? ) packages from a company.
# sentence_16: (dist :0.01943)
# 	 - The applicant has received employment claims from a Private Limited Company.
# sentence_17: (dist :0.01937)
# 	 - Now she is only claiming for $ 10,000.
# sentence_18: (dist :0.01926)
# 	 - Can she claim a refund.
#
# **keywords:**
# small claims, entire claim, private contractors, motorbike deposit, installation company, money order, contract interpretation, defective works, property developer, applicant file, small, case, settlement agreement, order, auction work, rental car, claim, applicant use water, company car, payments, renovation companies, adverse party, sure applicants, small claims tribunal, amount, tribunal order, years warranty issue, overtime pay, applicant, small claim tribunals, applicant claim, other remedies, company, court order, new claim, balance payment, ect sum, issue, client, bankrupt company, small cliams court, contractor-contractor say, money, pay, services, unpaid fees, applicant monies, applicant money, sct order, damage cost
